# %%
# !coconnect run py --help
# Out:
# Usage: coconnect run py [OPTIONS] COMMAND [ARGS]...
#
#   Commands for using python configurations to run the ETL transformation.
#
# Options:
#   --help  Show this message and exit.
#
# Commands:
#   list      List all the python classes there are available to run
#   make      Generate a python class from the OMOP mapping json
#   map       Perform OMOP Mapping given a python configuration file.
#   register  Register a python class with the tool
#   remove    remove a registered class

# %%
# !coconnect run py make --name ExampleDataset ../data/rules.json
# Out:
# Recreating file /Users/calummacdonald/Usher/CO-CONNECT/Software/tests/demo-dataset/notebooks/ExampleDataset.py

# %% [markdown]
# This automatically creates a file that looks like this:

# %%
# %load ExampleDataset.py
from coconnect.cdm import define_person, define_condition_occurrence, define_visit_occurrence, define_measurement, define_observation, define_drug_exposure
from coconnect.cdm import CommonDataModel
import json

class ExampleDataset(CommonDataModel):
    
    def __init__(self,**kwargs):
        """ 
        initialise the inputs and setup indexing 
        """
        super().__init__(**kwargs)
        
    
    @define_person
    def person_0(self):
        """
        Create CDM object for person
        """
        self.birth_datetime.series = self.inputs["Demographics.csv"]["Age"]
        self.gender_concept_id.series = self.inputs["Demographics.csv"]["Sex"]
        self.gender_source_concept_id.series = self.inputs["Demographics.csv"]["Sex"]
        self.gender_source_value.series = self.inputs["Demographics.csv"]["Sex"]
        self.person_id.series = self.inputs["Demographics.csv"]["ID"]
        
        # --- insert field operations --- 
        self.birth_datetime.series = self.tools.get_datetime_from_age(self.birth_datetime.series)
        
        # --- insert term mapping --- 
        self.gender_concept_id.series = self.gender_concept_id.series.map(
            {
                "Male": 8507
            }
        )
        self.gender_source_concept_id.series = self.gender_source_concept_id.series.map(
            {
                "Male": 8507
            }
        )
        
    @define_person
    def person_1(self):
        """
        Create CDM object for person
        """
        self.birth_datetime.series = self.inputs["Demographics.csv"]["Age"]
        self.gender_concept_id.series = self.inputs["Demographics.csv"]["Sex"]
        self.gender_source_concept_id.series = self.inputs["Demographics.csv"]["Sex"]
        self.gender_source_value.series = self.inputs["Demographics.csv"]["Sex"]
        self.person_id.series = self.inputs["Demographics.csv"]["ID"]
        
        # --- insert field operations --- 
        self.birth_datetime.series = self.tools.get_datetime_from_age(self.birth_datetime.series)
        
        # --- insert term mapping --- 
        self.gender_concept_id.series = self.gender_concept_id.series.map(
            {
                "Female": 8532
            }
        )
        self.gender_source_concept_id.series = self.gender_source_concept_id.series.map(
            {
                "Female": 8532
            }
        )
        
    @define_observation
    def observation_0(self):
        """
        Create CDM object for observation
        """
        self.observation_concept_id.series = self.inputs["Serology.csv"]["IgG"]
        self.observation_datetime.series = self.inputs["Serology.csv"]["Date"]
        self.observation_source_concept_id.series = self.inputs["Serology.csv"]["IgG"]
        self.observation_source_value.series = self.inputs["Serology.csv"]["IgG"]
        self.person_id.series = self.inputs["Serology.csv"]["ID"]
        
        # --- insert field operations --- 
        
        # --- insert term mapping --- 
        self.observation_concept_id.series = self.tools.make_scalar(self.observation_concept_id.series,4288455)
        self.observation_source_concept_id.series = self.tools.make_scalar(self.observation_source_concept_id.series,4288455)
        
    @define_observation
    def observation_1(self):
        """
        Create CDM object for observation
        """
        self.observation_concept_id.series = self.inputs["Hospital_Visit.csv"]["reason"]
        self.observation_datetime.series = self.inputs["Hospital_Visit.csv"]["admission_date"]
        self.observation_source_concept_id.series = self.inputs["Hospital_Visit.csv"]["reason"]
        self.observation_source_value.series = self.inputs["Hospital_Visit.csv"]["reason"]
        self.person_id.series = self.inputs["Hospital_Visit.csv"]["ID"]
        
        # --- insert field operations --- 
        
        # --- insert term mapping --- 
        self.observation_concept_id.series = self.observation_concept_id.series.map(
            {
                "Heart Attack": 4059317
            }
        )
        self.observation_source_concept_id.series = self.observation_source_concept_id.series.map(
            {
                "Heart Attack": 4059317
            }
        )
        
    @define_observation
    def observation_2(self):
        """
        Create CDM object for observation
        """
        self.observation_concept_id.series = self.inputs["Hospital_Visit.csv"]["reason"]
        self.observation_datetime.series = self.inputs["Hospital_Visit.csv"]["admission_date"]
        self.observation_source_concept_id.series = self.inputs["Hospital_Visit.csv"]["reason"]
        self.observation_source_value.series = self.inputs["Hospital_Visit.csv"]["reason"]
        self.person_id.series = self.inputs["Hospital_Visit.csv"]["ID"]
        
        # --- insert field operations --- 
        
        # --- insert term mapping --- 
        self.observation_concept_id.series = self.observation_concept_id.series.map(
            {
                "COVID-19": 37311065
            }
        )
        self.observation_source_concept_id.series = self.observation_source_concept_id.series.map(
            {
                "COVID-19": 37311065
            }
        )
        
    @define_observation
    def observation_3(self):
        """
        Create CDM object for observation
        """
        self.observation_concept_id.series = self.inputs["Hospital_Visit.csv"]["reason"]
        self.observation_datetime.series = self.inputs["Hospital_Visit.csv"]["admission_date"]
        self.observation_source_concept_id.series = self.inputs["Hospital_Visit.csv"]["reason"]
        self.observation_source_value.series = self.inputs["Hospital_Visit.csv"]["reason"]
        self.person_id.series = self.inputs["Hospital_Visit.csv"]["ID"]
        
        # --- insert field operations --- 
        
        # --- insert term mapping --- 
        self.observation_concept_id.series = self.observation_concept_id.series.map(
            {
                "Cancer": 40757663
            }
        )
        self.observation_source_concept_id.series = self.observation_source_concept_id.series.map(
            {
                "Cancer": 40757663
            }
        )
        
    @define_condition_occurrence
    def condition_occurrence_0(self):
        """
        Create CDM object for condition_occurrence
        """
        self.condition_concept_id.series = self.inputs["Symptoms.csv"]["Headache"]
        self.condition_end_datetime.series = self.inputs["Symptoms.csv"]["date_occurrence"]
        self.condition_source_concept_id.series = self.inputs["Symptoms.csv"]["Headache"]
        self.condition_source_value.series = self.inputs["Symptoms.csv"]["Headache"]
        self.condition_start_datetime.series = self.inputs["Symptoms.csv"]["date_occurrence"]
        self.person_id.series = self.inputs["Symptoms.csv"]["ID"]
        
        # --- insert field operations --- 
        
        # --- insert term mapping --- 
        self.condition_concept_id.series = self.condition_concept_id.series.map(
            {
                "Yes": 378253
            }
        )
        self.condition_source_concept_id.series = self.condition_source_concept_id.series.map(
            {
                "Yes": 378253
            }
        )
        
    @define_condition_occurrence
    def condition_occurrence_1(self):
        """
        Create CDM object for condition_occurrence
        """
        self.condition_concept_id.series = self.inputs["Symptoms.csv"]["Fatigue"]
        self.condition_end_datetime.series = self.inputs["Symptoms.csv"]["date_occurrence"]
        self.condition_source_concept_id.series = self.inputs["Symptoms.csv"]["Fatigue"]
        self.condition_source_value.series = self.inputs["Symptoms.csv"]["Fatigue"]
        self.condition_start_datetime.series = self.inputs["Symptoms.csv"]["date_occurrence"]
        self.person_id.series = self.inputs["Symptoms.csv"]["ID"]
        
        # --- insert field operations --- 
        
        # --- insert term mapping --- 
        self.condition_concept_id.series = self.condition_concept_id.series.map(
            {
                "Yes": 4223659
            }
        )
        self.condition_source_concept_id.series = self.condition_source_concept_id.series.map(
            {
                "Yes": 4223659
            }
        )
        
    @define_condition_occurrence
    def condition_occurrence_2(self):
        """
        Create CDM object for condition_occurrence
        """
        self.condition_concept_id.series = self.inputs["Symptoms.csv"]["Dizzy"]
        self.condition_end_datetime.series = self.inputs["Symptoms.csv"]["date_occurrence"]
        self.condition_source_concept_id.series = self.inputs["Symptoms.csv"]["Dizzy"]
        self.condition_source_value.series = self.inputs["Symptoms.csv"]["Dizzy"]
        self.condition_start_datetime.series = self.inputs["Symptoms.csv"]["date_occurrence"]
        self.person_id.series = self.inputs["Symptoms.csv"]["ID"]
        
        # --- insert field operations --- 
        
        # --- insert term mapping --- 
        self.condition_concept_id.series = self.condition_concept_id.series.map(
            {
                "Yes": 4223938
            }
        )
        self.condition_source_concept_id.series = self.condition_source_concept_id.series.map(
            {
                "Yes": 4223938
            }
        )
        
    @define_condition_occurrence
    def condition_occurrence_3(self):
        """
        Create CDM object for condition_occurrence
        """
        self.condition_concept_id.series = self.inputs["Symptoms.csv"]["Cough"]
        self.condition_end_datetime.series = self.inputs["Symptoms.csv"]["date_occurrence"]
        self.condition_source_concept_id.series = self.inputs["Symptoms.csv"]["Cough"]
        self.condition_source_value.series = self.inputs["Symptoms.csv"]["Cough"]
        self.condition_start_datetime.series = self.inputs["Symptoms.csv"]["date_occurrence"]
        self.person_id.series = self.inputs["Symptoms.csv"]["ID"]
        
        # --- insert field operations --- 
        
        # --- insert term mapping --- 
        self.condition_concept_id.series = self.condition_concept_id.series.map(
            {
                "Yes": 254761
            }
        )
        self.condition_source_concept_id.series = self.condition_source_concept_id.series.map(
            {
                "Yes": 254761
            }
        )
        
    @define_condition_occurrence
    def condition_occurrence_4(self):
        """
        Create CDM object for condition_occurrence
        """
        self.condition_concept_id.series = self.inputs["Symptoms.csv"]["Fever"]
        self.condition_end_datetime.series = self.inputs["Symptoms.csv"]["date_occurrence"]
        self.condition_source_concept_id.series = self.inputs["Symptoms.csv"]["Fever"]
        self.condition_source_value.series = self.inputs["Symptoms.csv"]["Fever"]
        self.condition_start_datetime.series = self.inputs["Symptoms.csv"]["date_occurrence"]
        self.person_id.series = self.inputs["Symptoms.csv"]["ID"]
        
        # --- insert field operations --- 
        
        # --- insert term mapping --- 
        self.condition_concept_id.series = self.condition_concept_id.series.map(
            {
                "Yes": 437663
            }
        )
        self.condition_source_concept_id.series = self.condition_source_concept_id.series.map(
            {
                "Yes": 437663
            }
        )
        
    @define_condition_occurrence
    def condition_occurrence_5(self):
        """
        Create CDM object for condition_occurrence
        """
        self.condition_concept_id.series = self.inputs["Symptoms.csv"]["Muscle_Pain"]
        self.condition_end_datetime.series = self.inputs["Symptoms.csv"]["date_occurrence"]
        self.condition_source_concept_id.series = self.inputs["Symptoms.csv"]["Muscle_Pain"]
        self.condition_source_value.series = self.inputs["Symptoms.csv"]["Muscle_Pain"]
        self.condition_start_datetime.series = self.inputs["Symptoms.csv"]["date_occurrence"]
        self.person_id.series = self.inputs["Symptoms.csv"]["ID"]
        
        # --- insert field operations --- 
        
        # --- insert term mapping --- 
        self.condition_concept_id.series = self.condition_concept_id.series.map(
            {
                "Yes": 442752
            }
        )
        self.condition_source_concept_id.series = self.condition_source_concept_id.series.map(
            {
                "Yes": 442752
            }
        )
        
    @define_condition_occurrence
    def condition_occurrence_6(self):
        """
        Create CDM object for condition_occurrence
        """
        self.condition_concept_id.series = self.inputs["Hospital_Visit.csv"]["reason"]
        self.condition_end_datetime.series = self.inputs["Hospital_Visit.csv"]["admission_date"]
        self.condition_source_concept_id.series = self.inputs["Hospital_Visit.csv"]["reason"]
        self.condition_source_value.series = self.inputs["Hospital_Visit.csv"]["reason"]
        self.condition_start_datetime.series = self.inputs["Hospital_Visit.csv"]["admission_date"]
        self.person_id.series = self.inputs["Hospital_Visit.csv"]["ID"]
        
        # --- insert field operations --- 
        
        # --- insert term mapping --- 
        self.condition_concept_id.series = self.condition_concept_id.series.map(
            {
                "Pneumonia": 255848
            }
        )
        self.condition_source_concept_id.series = self.condition_source_concept_id.series.map(
            {
                "Pneumonia": 255848
            }
        )
        
    @define_condition_occurrence
    def condition_occurrence_7(self):
        """
        Create CDM object for condition_occurrence
        """
        self.condition_concept_id.series = self.inputs["GP_Records.csv"]["comorbidity"]
        self.condition_end_datetime.series = self.inputs["GP_Records.csv"]["date_of_visit"]
        self.condition_source_concept_id.series = self.inputs["GP_Records.csv"]["comorbidity"]
        self.condition_source_value.series = self.inputs["GP_Records.csv"]["comorbidity"]
        self.condition_start_datetime.series = self.inputs["GP_Records.csv"]["date_of_visit"]
        self.person_id.series = self.inputs["GP_Records.csv"]["ID"]
        
        # --- insert field operations --- 
        
        # --- insert term mapping --- 
        self.condition_concept_id.series = self.condition_concept_id.series.map(
            {
                "Mental Health": 4131548
            }
        )
        self.condition_source_concept_id.series = self.condition_source_concept_id.series.map(
            {
                "Mental Health": 4131548
            }
        )
        
    @define_condition_occurrence
    def condition_occurrence_8(self):
        """
        Create CDM object for condition_occurrence
        """
        self.condition_concept_id.series = self.inputs["GP_Records.csv"]["comorbidity"]
        self.condition_end_datetime.series = self.inputs["GP_Records.csv"]["date_of_visit"]
        self.condition_source_concept_id.series = self.inputs["GP_Records.csv"]["comorbidity"]
        self.condition_source_value.series = self.inputs["GP_Records.csv"]["comorbidity"]
        self.condition_start_datetime.series = self.inputs["GP_Records.csv"]["date_of_visit"]
        self.person_id.series = self.inputs["GP_Records.csv"]["ID"]
        
        # --- insert field operations --- 
        
        # --- insert term mapping --- 
        self.condition_concept_id.series = self.condition_concept_id.series.map(
            {
                "Mental Health": 432586
            }
        )
        self.condition_source_concept_id.series = self.condition_source_concept_id.series.map(
            {
                "Mental Health": 432586
            }
        )
        
    @define_condition_occurrence
    def condition_occurrence_9(self):
        """
        Create CDM object for condition_occurrence
        """
        self.condition_concept_id.series = self.inputs["GP_Records.csv"]["comorbidity"]
        self.condition_end_datetime.series = self.inputs["GP_Records.csv"]["date_of_visit"]
        self.condition_source_concept_id.series = self.inputs["GP_Records.csv"]["comorbidity"]
        self.condition_source_value.series = self.inputs["GP_Records.csv"]["comorbidity"]
        self.condition_start_datetime.series = self.inputs["GP_Records.csv"]["date_of_visit"]
        self.person_id.series = self.inputs["GP_Records.csv"]["ID"]
        
        # --- insert field operations --- 
        
        # --- insert term mapping --- 
        self.condition_concept_id.series = self.condition_concept_id.series.map(
            {
                "Diabetes Type-II": 201826
            }
        )
        self.condition_source_concept_id.series = self.condition_source_concept_id.series.map(
            {
                "Diabetes Type-II": 201826
            }
        )
        
    @define_condition_occurrence
    def condition_occurrence_10(self):
        """
        Create CDM object for condition_occurrence
        """
        self.condition_concept_id.series = self.inputs["GP_Records.csv"]["comorbidity"]
        self.condition_end_datetime.series = self.inputs["GP_Records.csv"]["date_of_visit"]
        self.condition_source_concept_id.series = self.inputs["GP_Records.csv"]["comorbidity"]
        self.condition_source_value.series = self.inputs["GP_Records.csv"]["comorbidity"]
        self.condition_start_datetime.series = self.inputs["GP_Records.csv"]["date_of_visit"]
        self.person_id.series = self.inputs["GP_Records.csv"]["ID"]
        
        # --- insert field operations --- 
        
        # --- insert term mapping --- 
        self.condition_concept_id.series = self.condition_concept_id.series.map(
            {
                "Heart Condition": 4185932
            }
        )
        self.condition_source_concept_id.series = self.condition_source_concept_id.series.map(
            {
                "Heart Condition": 4185932
            }
        )
        
    @define_condition_occurrence
    def condition_occurrence_11(self):
        """
        Create CDM object for condition_occurrence
        """
        self.condition_concept_id.series = self.inputs["GP_Records.csv"]["comorbidity"]
        self.condition_end_datetime.series = self.inputs["GP_Records.csv"]["date_of_visit"]
        self.condition_source_concept_id.series = self.inputs["GP_Records.csv"]["comorbidity"]
        self.condition_source_value.series = self.inputs["GP_Records.csv"]["comorbidity"]
        self.condition_start_datetime.series = self.inputs["GP_Records.csv"]["date_of_visit"]
        self.person_id.series = self.inputs["GP_Records.csv"]["ID"]
        
        # --- insert field operations --- 
        
        # --- insert term mapping --- 
        self.condition_concept_id.series = self.condition_concept_id.series.map(
            {
                "High Blood Pressure": 316866
            }
        )
        self.condition_source_concept_id.series = self.condition_source_concept_id.series.map(
            {
                "High Blood Pressure": 316866
            }
        )
        
    @define_drug_exposure
    def drug_exposure_0(self):
        """
        Create CDM object for drug_exposure
        """
        self.drug_concept_id.series = self.inputs["Vaccinations.csv"]["type"]
        self.drug_exposure_end_datetime.series = self.inputs["Vaccinations.csv"]["date_of_vaccination"]
        self.drug_exposure_start_datetime.series = self.inputs["Vaccinations.csv"]["date_of_vaccination"]
        self.drug_source_concept_id.series = self.inputs["Vaccinations.csv"]["type"]
        self.drug_source_value.series = self.inputs["Vaccinations.csv"]["type"]
        self.person_id.series = self.inputs["Vaccinations.csv"]["ID"]
        
        # --- insert field operations --- 
        
        # --- insert term mapping --- 
        self.drug_concept_id.series = self.drug_concept_id.series.map(
            {
                "Moderna": 35894915
            }
        )
        self.drug_source_concept_id.series = self.drug_source_concept_id.series.map(
            {
                "Moderna": 35894915
            }
        )
        
    @define_drug_exposure
    def drug_exposure_1(self):
        """
        Create CDM object for drug_exposure
        """
        self.drug_concept_id.series = self.inputs["Vaccinations.csv"]["type"]
        self.drug_exposure_end_datetime.series = self.inputs["Vaccinations.csv"]["date_of_vaccination"]
        self.drug_exposure_start_datetime.series = self.inputs["Vaccinations.csv"]["date_of_vaccination"]
        self.drug_source_concept_id.series = self.inputs["Vaccinations.csv"]["type"]
        self.drug_source_value.series = self.inputs["Vaccinations.csv"]["type"]
        self.person_id.series = self.inputs["Vaccinations.csv"]["ID"]
        
        # --- insert field operations --- 
        
        # --- insert term mapping --- 
        self.drug_concept_id.series = self.drug_concept_id.series.map(
            {
                "AstraZenica": 35894915
            }
        )
        self.drug_source_concept_id.series = self.drug_source_concept_id.series.map(
            {
                "AstraZenica": 35894915
            }
        )
        
    @define_drug_exposure
    def drug_exposure_2(self):
        """
        Create CDM object for drug_exposure
        """
        self.drug_concept_id.series = self.inputs["Vaccinations.csv"]["type"]
        self.drug_exposure_end_datetime.series = self.inputs["Vaccinations.csv"]["date_of_vaccination"]
        self.drug_exposure_start_datetime.series = self.inputs["Vaccinations.csv"]["date_of_vaccination"]
        self.drug_source_concept_id.series = self.inputs["Vaccinations.csv"]["type"]
        self.drug_source_value.series = self.inputs["Vaccinations.csv"]["type"]
        self.person_id.series = self.inputs["Vaccinations.csv"]["ID"]
        
        # --- insert field operations --- 
        
        # --- insert term mapping --- 
        self.drug_concept_id.series = self.drug_concept_id.series.map(
            {
                "Pfizer": 35894915
            }
        )
        self.drug_source_concept_id.series = self.drug_source_concept_id.series.map(
            {
                "Pfizer": 35894915
            }
        )
        
    @define_drug_exposure
    def drug_exposure_3(self):
        """
        Create CDM object for drug_exposure
        """
        self.drug_concept_id.series = self.inputs["Vaccinations.csv"]["type"]
        self.drug_exposure_end_datetime.series = self.inputs["Vaccinations.csv"]["date_of_vaccination"]
        self.drug_exposure_start_datetime.series = self.inputs["Vaccinations.csv"]["date_of_vaccination"]
        self.drug_source_concept_id.series = self.inputs["Vaccinations.csv"]["type"]
        self.drug_source_value.series = self.inputs["Vaccinations.csv"]["type"]
        self.person_id.series = self.inputs["Vaccinations.csv"]["ID"]
        
        # --- insert field operations --- 
        
        # --- insert term mapping --- 
        self.drug_concept_id.series = self.drug_concept_id.series.map(
            {
                "Moderna": 37003518
            }
        )
        self.drug_source_concept_id.series = self.drug_source_concept_id.series.map(
            {
                "Moderna": 37003518
            }
        )
        
    @define_drug_exposure
    def drug_exposure_4(self):
        """
        Create CDM object for drug_exposure
        """
        self.drug_concept_id.series = self.inputs["Vaccinations.csv"]["type"]
        self.drug_exposure_end_datetime.series = self.inputs["Vaccinations.csv"]["date_of_vaccination"]
        self.drug_exposure_start_datetime.series = self.inputs["Vaccinations.csv"]["date_of_vaccination"]
        self.drug_source_concept_id.series = self.inputs["Vaccinations.csv"]["type"]
        self.drug_source_value.series = self.inputs["Vaccinations.csv"]["type"]
        self.person_id.series = self.inputs["Vaccinations.csv"]["ID"]
        
        # --- insert field operations --- 
        
        # --- insert term mapping --- 
        self.drug_concept_id.series = self.drug_concept_id.series.map(
            {
                "Pfizer": 37003436
            }
        )
        self.drug_source_concept_id.series = self.drug_source_concept_id.series.map(
            {
                "Pfizer": 37003436
            }
        )

# %% [markdown]
# Loading some inputs..

# %%
import coconnect
import glob
inputs = coconnect.tools.load_csv(glob.glob('../data/part1/*'))
inputs
# Out:
# 2022-03-16 14:45:48 - LocalDataCollection - INFO - DataCollection Object Created
# 2022-03-16 14:45:48 - LocalDataCollection - INFO - Registering  Symptoms.csv [<coconnect.io.common.DataBrick object at 0x109534430>]
# 2022-03-16 14:45:48 - LocalDataCollection - INFO - Registering  Blood_Test.csv [<coconnect.io.common.DataBrick object at 0x1093bfdf0>]
# 2022-03-16 14:45:48 - LocalDataCollection - INFO - Registering  Serology.csv [<coconnect.io.common.DataBrick object at 0x1093bfa30>]
# 2022-03-16 14:45:49 - LocalDataCollection - INFO - Registering  GP_Records.csv [<coconnect.io.common.DataBrick object at 0x1093bf220>]
# 2022-03-16 14:45:49 - LocalDataCollection - INFO - Registering  Vaccinations.csv [<coconnect.io.common.DataBrick object at 0x1093bf280>]
# 2022-03-16 14:45:49 - LocalDataCollection - INFO - Registering  Hospital_Visit.csv [<coconnect.io.common.DataBrick object at 0x1093bf430>]
# 2022-03-16 14:45:49 - LocalDataCollection - INFO - Registering  pks.csv [<coconnect.io.common.DataBrick object at 0x10ced1f40>]
# 2022-03-16 14:45:49 - LocalDataCollection - INFO - Registering  Demographics.csv [<coconnect.io.common.DataBrick object at 0x10ced1e80>]

# %% [markdown]
# A new instances can be created from the created python class

# %%
instance = ExampleDataset(inputs=inputs)
instance
# Out:
# 2022-03-17 10:52:54 - ExampleDataset - INFO - CommonDataModel (5.3.1) created with co-connect-tools version 0.0.0
# 2022-03-17 10:52:54 - ExampleDataset - INFO - Running with an DataCollection object
# 2022-03-17 10:52:54 - ExampleDataset - INFO - Turning on automatic cdm column filling
# 2022-03-17 10:52:54 - ExampleDataset - INFO - Added condition_occurrence_0 of type condition_occurrence
# 2022-03-17 10:52:54 - ExampleDataset - INFO - Added condition_occurrence_1 of type condition_occurrence
# 2022-03-17 10:52:54 - ExampleDataset - INFO - Added condition_occurrence_10 of type condition_occurrence
# 2022-03-17 10:52:54 - ExampleDataset - INFO - Added condition_occurrence_11 of type condition_occurrence
# 2022-03-17 10:52:54 - ExampleDataset - INFO - Added condition_occurrence_2 of type condition_occurrence
# 2022-03-17 10:52:54 - ExampleDataset - INFO - Added condition_occurrence_3 of type condition_occurrence
# 2022-03-17 10:52:54 - ExampleDataset - INFO - Added condition_occurrence_4 of type condition_occurrence
# 2022-03-17 10:52:54 - ExampleDataset - INFO - Added condition_occurrence_5 of type condition_occurrence
# 2022-03-17 10:52:54 - ExampleDataset - INFO - Added condition_occurrence_6 of type condition_occurrence
# 2022-03-17 10:52:54 - ExampleDataset - INFO - Added condition_occurrence_7 of type condition_occurrence
# 2022-03-17 10:52:54 - ExampleDataset - INFO - Added condition_occurrence_8 of type condition_occurrence
# 2022-03-17 10:52:54 - ExampleDataset - INFO - Added condition_occurrence_9 of type condition_occurrence
# 2022-03-17 10:52:54 - ExampleDataset - INFO - Added drug_exposure_0 of type drug_exposure
# 2022-03-17 10:52:54 - ExampleDataset - INFO - Added drug_exposure_1 of type drug_exposure
# 2022-03-17 10:52:54 - ExampleDataset - INFO - Added drug_exposure_2 of type drug_exposure
# 2022-03-17 10:52:54 - ExampleDataset - INFO - Added drug_exposure_3 of type drug_exposure
# 2022-03-17 10:52:54 - ExampleDataset - INFO - Added drug_exposure_4 of type drug_exposure
# 2022-03-17 10:52:54 - ExampleDataset - INFO - Added observation_0 of type observation
# 2022-03-17 10:52:54 - ExampleDataset - INFO - Added observation_1 of type observation
# 2022-03-17 10:52:54 - ExampleDataset - INFO - Added observation_2 of type observation
# 2022-03-17 10:52:54 - ExampleDataset - INFO - Added observation_3 of type observation
# 2022-03-17 10:52:54 - ExampleDataset - INFO - Added person_0 of type person
# 2022-03-17 10:52:54 - ExampleDataset - INFO - Added person_1 of type person

# %%
instance.process()
# Out:
# 2022-03-17 10:52:58 - ExampleDataset - INFO - Starting processing in order: ['person', 'condition_occurrence', 'drug_exposure', 'observation']
# 2022-03-17 10:52:58 - ExampleDataset - INFO - Number of objects to process for each table...
# {
#       "condition_occurrence": 12,
#       "drug_exposure": 5,
#       "observation": 4,
#       "person": 2
# }
# 2022-03-17 10:52:58 - ExampleDataset - INFO - for person: found 2 objects
# 2022-03-17 10:52:58 - ExampleDataset - INFO - working on person
# 2022-03-17 10:52:58 - ExampleDataset - INFO - starting on person_0
# 2022-03-17 10:52:58 - LocalDataCollection - INFO - Retrieving initial dataframe for 'Demographics.csv' for the first time
# 2022-03-17 10:52:59 - Person - WARNING - Requiring non-null values in gender_concept_id removed 45025 rows, leaving 54975 rows.
# 2022-03-17 10:52:59 - Person - INFO - Automatically formatting data columns.
# 2022-03-17 10:53:00 - Person - INFO - created df (0x133dfa9d0)[person_0]
# 2022-03-17 10:53:00 - ExampleDataset - INFO - finished person_0 (0x133dfa9d0) ... 1/2 completed, 54975 rows
# 2022-03-17 10:53:00 - ExampleDataset - INFO - starting on person_1
# 2022-03-17 10:53:02 - Person - WARNING - Requiring non-null values in gender_concept_id removed 55494 rows, leaving 44506 rows.
# 2022-03-17 10:53:02 - Person - INFO - Automatically formatting data columns.
# 2022-03-17 10:53:02 - Person - INFO - created df (0x133901a00)[person_1]
# 2022-03-17 10:53:02 - ExampleDataset - INFO - finished person_1 (0x133901a00) ... 2/2 completed, 44506 rows
# 2022-03-17 10:53:03 - ExampleDataset - INFO - called save_dateframe but outputs are not defined. save_files: True
# 2022-03-17 10:53:03 - ExampleDataset - INFO - finalised person on iteration 0 producing 99481 rows from 2 tables
# 2022-03-17 10:53:03 - LocalDataCollection - INFO - Getting next chunk of data
# 2022-03-17 10:53:03 - LocalDataCollection - INFO - All input files for this object have now been used.
# 2022-03-17 10:53:03 - LocalDataCollection - INFO - resetting used bricks
# 2022-03-17 10:53:03 - ExampleDataset - INFO - for condition_occurrence: found 12 objects
# 2022-03-17 10:53:03 - ExampleDataset - INFO - working on condition_occurrence
# 2022-03-17 10:53:03 - ExampleDataset - INFO - starting on condition_occurrence_0
# 2022-03-17 10:53:03 - LocalDataCollection - INFO - Retrieving initial dataframe for 'Symptoms.csv' for the first time
# 2022-03-17 10:53:03 - ConditionOccurrence - WARNING - Requiring non-null values in condition_concept_id removed 6565 rows, leaving 26435 rows.
# 2022-03-17 10:53:03 - ConditionOccurrence - WARNING - Requiring non-null values in condition_start_datetime removed 140 rows, leaving 26295 rows.
# 2022-03-17 10:53:03 - ConditionOccurrence - INFO - Automatically formatting data columns.
# 2022-03-17 10:53:04 - ConditionOccurrence - INFO - created df (0x133dfaac0)[condition_occurrence_0]
# 2022-03-17 10:53:04 - ExampleDataset - INFO - finished condition_occurrence_0 (0x133dfaac0) ... 1/12 completed, 26295 rows
# 2022-03-17 10:53:04 - ExampleDataset - ERROR - There are person_ids in this table that are not in the output person table!
# 2022-03-17 10:53:04 - ExampleDataset - ERROR - Either they are not in the original data, or while creating the person table,
# 2022-03-17 10:53:04 - ExampleDataset - ERROR - studies have been removed due to lack of required fields, such as birthdate.
# 2022-03-17 10:53:04 - ExampleDataset - ERROR - 26171/26295 were good, 124 studies are removed.
# 2022-03-17 10:53:04 - ExampleDataset - INFO - starting on condition_occurrence_1
# 2022-03-17 10:53:04 - ConditionOccurrence - WARNING - Requiring non-null values in condition_concept_id removed 9923 rows, leaving 23077 rows.
# 2022-03-17 10:53:04 - ConditionOccurrence - WARNING - Requiring non-null values in condition_start_datetime removed 118 rows, leaving 22959 rows.
# 2022-03-17 10:53:04 - ConditionOccurrence - INFO - Automatically formatting data columns.
# 2022-03-17 10:53:05 - ConditionOccurrence - INFO - created df (0x135a7a400)[condition_occurrence_1]
# 2022-03-17 10:53:06 - ExampleDataset - INFO - finished condition_occurrence_1 (0x135a7a400) ... 2/12 completed, 22959 rows
# 2022-03-17 10:53:06 - ExampleDataset - ERROR - There are person_ids in this table that are not in the output person table!
# 2022-03-17 10:53:06 - ExampleDataset - ERROR - Either they are not in the original data, or while creating the person table,
# 2022-03-17 10:53:06 - ExampleDataset - ERROR - studies have been removed due to lack of required fields, such as birthdate.
# 2022-03-17 10:53:06 - ExampleDataset - ERROR - 22842/22959 were good, 117 studies are removed.
# 2022-03-17 10:53:06 - ExampleDataset - INFO - starting on condition_occurrence_10
# 2022-03-17 10:53:06 - LocalDataCollection - INFO - Retrieving initial dataframe for 'GP_Records.csv' for the first time
# 2022-03-17 10:53:06 - ConditionOccurrence - WARNING - Requiring non-null values in condition_concept_id removed 174542 rows, leaving 19939 rows.
# 2022-03-17 10:53:06 - ConditionOccurrence - INFO - Automatically formatting data columns.
# 2022-03-17 10:53:07 - ConditionOccurrence - INFO - created df (0x13662d430)[condition_occurrence_10]
# 2022-03-17 10:53:07 - ExampleDataset - INFO - finished condition_occurrence_10 (0x13662d430) ... 3/12 completed, 19939 rows
# 2022-03-17 10:53:07 - ExampleDataset - ERROR - There are person_ids in this table that are not in the output person table!
# 2022-03-17 10:53:07 - ExampleDataset - ERROR - Either they are not in the original data, or while creating the person table,
# 2022-03-17 10:53:07 - ExampleDataset - ERROR - studies have been removed due to lack of required fields, such as birthdate.
# 2022-03-17 10:53:07 - ExampleDataset - ERROR - 19831/19939 were good, 108 studies are removed.
# 2022-03-17 10:53:07 - ExampleDataset - INFO - starting on condition_occurrence_11
# 2022-03-17 10:53:08 - ConditionOccurrence - WARNING - Requiring non-null values in condition_concept_id removed 181635 rows, leaving 12846 rows.
# 2022-03-17 10:53:08 - ConditionOccurrence - INFO - Automatically formatting data columns.
# 2022-03-17 10:53:08 - ConditionOccurrence - INFO - created df (0x133901130)[condition_occurrence_11]
# 2022-03-17 10:53:08 - ExampleDataset - INFO - finished condition_occurrence_11 (0x133901130) ... 4/12 completed, 12846 rows
# 2022-03-17 10:53:08 - ExampleDataset - ERROR - There are person_ids in this table that are not in the output person table!
# 2022-03-17 10:53:09 - ExampleDataset - ERROR - Either they are not in the original data, or while creating the person table,
# 2022-03-17 10:53:09 - ExampleDataset - ERROR - studies have been removed due to lack of required fields, such as birthdate.
# 2022-03-17 10:53:09 - ExampleDataset - ERROR - 12773/12846 were good, 73 studies are removed.
# 2022-03-17 10:53:09 - ExampleDataset - INFO - starting on condition_occurrence_2
# 2022-03-17 10:53:09 - ConditionOccurrence - WARNING - Requiring non-null values in condition_concept_id removed 19892 rows, leaving 13108 rows.
# 2022-03-17 10:53:09 - ConditionOccurrence - WARNING - Requiring non-null values in condition_start_datetime removed 62 rows, leaving 13046 rows.
# 2022-03-17 10:53:09 - ConditionOccurrence - INFO - Automatically formatting data columns.
# 2022-03-17 10:53:09 - ConditionOccurrence - INFO - created df (0x13662d6a0)[condition_occurrence_2]
# 2022-03-17 10:53:09 - ExampleDataset - INFO - finished condition_occurrence_2 (0x13662d6a0) ... 5/12 completed, 13046 rows
# 2022-03-17 10:53:09 - ExampleDataset - ERROR - There are person_ids in this table that are not in the output person table!
# 2022-03-17 10:53:09 - ExampleDataset - ERROR - Either they are not in the original data, or while creating the person table,
# 2022-03-17 10:53:09 - ExampleDataset - ERROR - studies have been removed due to lack of required fields, such as birthdate.
# 2022-03-17 10:53:09 - ExampleDataset - ERROR - 12983/13046 were good, 63 studies are removed.
# 2022-03-17 10:53:09 - ExampleDataset - INFO - starting on condition_occurrence_3
# 2022-03-17 10:53:09 - ConditionOccurrence - WARNING - Requiring non-null values in condition_concept_id removed 10081 rows, leaving 22919 rows.
# 2022-03-17 10:53:09 - ConditionOccurrence - WARNING - Requiring non-null values in condition_start_datetime removed 114 rows, leaving 22805 rows.
# 2022-03-17 10:53:09 - ConditionOccurrence - INFO - Automatically formatting data columns.
# 2022-03-17 10:53:10 - ConditionOccurrence - INFO - created df (0x1372f94c0)[condition_occurrence_3]
# 2022-03-17 10:53:11 - ExampleDataset - INFO - finished condition_occurrence_3 (0x1372f94c0) ... 6/12 completed, 22805 rows
# 2022-03-17 10:53:11 - ExampleDataset - ERROR - There are person_ids in this table that are not in the output person table!
# 2022-03-17 10:53:11 - ExampleDataset - ERROR - Either they are not in the original data, or while creating the person table,
# 2022-03-17 10:53:11 - ExampleDataset - ERROR - studies have been removed due to lack of required fields, such as birthdate.
# 2022-03-17 10:53:11 - ExampleDataset - ERROR - 22691/22805 were good, 114 studies are removed.
# 2022-03-17 10:53:11 - ExampleDataset - INFO - starting on condition_occurrence_4
# 2022-03-17 10:53:11 - ConditionOccurrence - WARNING - Requiring non-null values in condition_concept_id removed 26409 rows, leaving 6591 rows.
# 2022-03-17 10:53:11 - ConditionOccurrence - WARNING - Requiring non-null values in condition_start_datetime removed 34 rows, leaving 6557 rows.
# 2022-03-17 10:53:11 - ConditionOccurrence - INFO - Automatically formatting data columns.
# 2022-03-17 10:53:11 - ConditionOccurrence - INFO - created df (0x13662d4f0)[condition_occurrence_4]
# 2022-03-17 10:53:11 - ExampleDataset - INFO - finished condition_occurrence_4 (0x13662d4f0) ... 7/12 completed, 6557 rows
# 2022-03-17 10:53:12 - ExampleDataset - ERROR - There are person_ids in this table that are not in the output person table!
# 2022-03-17 10:53:12 - ExampleDataset - ERROR - Either they are not in the original data, or while creating the person table,
# 2022-03-17 10:53:12 - ExampleDataset - ERROR - studies have been removed due to lack of required fields, such as birthdate.
# 2022-03-17 10:53:12 - ExampleDataset - ERROR - 6520/6557 were good, 37 studies are removed.
# 2022-03-17 10:53:12 - ExampleDataset - INFO - starting on condition_occurrence_5
# 2022-03-17 10:53:12 - ConditionOccurrence - WARNING - Requiring non-null values in condition_concept_id removed 29679 rows, leaving 3321 rows.
# 2022-03-17 10:53:12 - ConditionOccurrence - WARNING - Requiring non-null values in condition_start_datetime removed 22 rows, leaving 3299 rows.
# 2022-03-17 10:53:12 - ConditionOccurrence - INFO - Automatically formatting data columns.
# 2022-03-17 10:53:12 - ConditionOccurrence - INFO - created df (0x1372f94f0)[condition_occurrence_5]
# 2022-03-17 10:53:12 - ExampleDataset - INFO - finished condition_occurrence_5 (0x1372f94f0) ... 8/12 completed, 3299 rows
# 2022-03-17 10:53:12 - ExampleDataset - ERROR - There are person_ids in this table that are not in the output person table!
# 2022-03-17 10:53:12 - ExampleDataset - ERROR - Either they are not in the original data, or while creating the person table,
# 2022-03-17 10:53:12 - ExampleDataset - ERROR - studies have been removed due to lack of required fields, such as birthdate.
# 2022-03-17 10:53:12 - ExampleDataset - ERROR - 3279/3299 were good, 20 studies are removed.
# 2022-03-17 10:53:12 - ExampleDataset - INFO - starting on condition_occurrence_6
# 2022-03-17 10:53:12 - LocalDataCollection - INFO - Retrieving initial dataframe for 'Hospital_Visit.csv' for the first time
# 2022-03-17 10:53:12 - ConditionOccurrence - WARNING - Requiring non-null values in condition_concept_id removed 102019 rows, leaving 17981 rows.
# 2022-03-17 10:53:12 - ConditionOccurrence - INFO - Automatically formatting data columns.
# 2022-03-17 10:53:13 - ConditionOccurrence - INFO - created df (0x137c1e430)[condition_occurrence_6]
# 2022-03-17 10:53:13 - ExampleDataset - INFO - finished condition_occurrence_6 (0x137c1e430) ... 9/12 completed, 17981 rows
# 2022-03-17 10:53:13 - ExampleDataset - ERROR - There are person_ids in this table that are not in the output person table!
# 2022-03-17 10:53:13 - ExampleDataset - ERROR - Either they are not in the original data, or while creating the person table,
# 2022-03-17 10:53:13 - ExampleDataset - ERROR - studies have been removed due to lack of required fields, such as birthdate.
# 2022-03-17 10:53:13 - ExampleDataset - ERROR - 17880/17981 were good, 101 studies are removed.
# 2022-03-17 10:53:13 - ExampleDataset - INFO - starting on condition_occurrence_7
# 2022-03-17 10:53:13 - ConditionOccurrence - WARNING - Requiring non-null values in condition_concept_id removed 148340 rows, leaving 46141 rows.
# 2022-03-17 10:53:13 - ConditionOccurrence - INFO - Automatically formatting data columns.
# 2022-03-17 10:53:15 - ConditionOccurrence - INFO - created df (0x137c1e190)[condition_occurrence_7]
# 2022-03-17 10:53:15 - ExampleDataset - INFO - finished condition_occurrence_7 (0x137c1e190) ... 10/12 completed, 46141 rows
# 2022-03-17 10:53:16 - ExampleDataset - ERROR - There are person_ids in this table that are not in the output person table!
# 2022-03-17 10:53:16 - ExampleDataset - ERROR - Either they are not in the original data, or while creating the person table,
# 2022-03-17 10:53:16 - ExampleDataset - ERROR - studies have been removed due to lack of required fields, such as birthdate.
# 2022-03-17 10:53:16 - ExampleDataset - ERROR - 45893/46141 were good, 248 studies are removed.
# 2022-03-17 10:53:16 - ExampleDataset - INFO - starting on condition_occurrence_8
# 2022-03-17 10:53:16 - ConditionOccurrence - WARNING - Requiring non-null values in condition_concept_id removed 148340 rows, leaving 46141 rows.
# 2022-03-17 10:53:16 - ConditionOccurrence - INFO - Automatically formatting data columns.
# 2022-03-17 10:53:17 - ConditionOccurrence - INFO - created df (0x137c1e370)[condition_occurrence_8]
# 2022-03-17 10:53:18 - ExampleDataset - INFO - finished condition_occurrence_8 (0x137c1e370) ... 11/12 completed, 46141 rows
# 2022-03-17 10:53:18 - ExampleDataset - ERROR - There are person_ids in this table that are not in the output person table!
# 2022-03-17 10:53:18 - ExampleDataset - ERROR - Either they are not in the original data, or while creating the person table,
# 2022-03-17 10:53:18 - ExampleDataset - ERROR - studies have been removed due to lack of required fields, such as birthdate.
# 2022-03-17 10:53:18 - ExampleDataset - ERROR - 45893/46141 were good, 248 studies are removed.
# 2022-03-17 10:53:18 - ExampleDataset - INFO - starting on condition_occurrence_9
# 2022-03-17 10:53:18 - ConditionOccurrence - WARNING - Requiring non-null values in condition_concept_id removed 168926 rows, leaving 25555 rows.
# 2022-03-17 10:53:18 - ConditionOccurrence - INFO - Automatically formatting data columns.
# 2022-03-17 10:53:19 - ConditionOccurrence - INFO - created df (0x13662d4c0)[condition_occurrence_9]
# 2022-03-17 10:53:19 - ExampleDataset - INFO - finished condition_occurrence_9 (0x13662d4c0) ... 12/12 completed, 25555 rows
# 2022-03-17 10:53:19 - ExampleDataset - ERROR - There are person_ids in this table that are not in the output person table!
# 2022-03-17 10:53:19 - ExampleDataset - ERROR - Either they are not in the original data, or while creating the person table,
# 2022-03-17 10:53:19 - ExampleDataset - ERROR - studies have been removed due to lack of required fields, such as birthdate.
# 2022-03-17 10:53:19 - ExampleDataset - ERROR - 25424/25555 were good, 131 studies are removed.
# 2022-03-17 10:53:20 - ExampleDataset - ERROR - Removed 45 row(s) due to duplicates found when merging condition_occurrence
# 2022-03-17 10:53:20 - ExampleDataset - WARNING - Example duplicates...
# 2022-03-17 10:53:20 - ExampleDataset - WARNING -                          person_id  condition_concept_id condition_start_date  \
# condition_occurrence_id
# 324                        59955.0                378253           2021-04-15
# 325                        59955.0                378253           2021-04-15
# 789                         7068.0                378253           2021-02-07
# 790                         7068.0                378253           2021-02-07
# 1814                        9026.0                378253           2021-03-01
# 1815                        9026.0                378253           2021-03-01
# 2361                       63112.0                378253           2020-07-13
# 2362                       63112.0                378253           2020-07-13
# 2703                       55818.0                378253           2021-07-06
# 2705                       55818.0                378253           2021-07-06
#
#                            condition_start_datetime condition_end_date  \
# condition_occurrence_id
# 324                      2021-04-15 00:00:00.000000         2021-04-15
# 325                      2021-04-15 00:00:00.000000         2021-04-15
# 789                      2021-02-07 00:00:00.000000         2021-02-07
# 790                      2021-02-07 00:00:00.000000         2021-02-07
# 1814                     2021-03-01 00:00:00.000000         2021-03-01
# 1815                     2021-03-01 00:00:00.000000         2021-03-01
# 2361                     2020-07-13 00:00:00.000000         2020-07-13
# 2362                     2020-07-13 00:00:00.000000         2020-07-13
# 2703                     2021-07-06 00:00:00.000000         2021-07-06
# 2705                     2021-07-06 00:00:00.000000         2021-07-06
#
#                              condition_end_datetime condition_source_value  \
# condition_occurrence_id
# 324                      2021-04-15 00:00:00.000000                    Yes
# 325                      2021-04-15 00:00:00.000000                    Yes
# 789                      2021-02-07 00:00:00.000000                    Yes
# 790                      2021-02-07 00:00:00.000000                    Yes
# 1814                     2021-03-01 00:00:00.000000                    Yes
# 1815                     2021-03-01 00:00:00.000000                    Yes
# 2361                     2020-07-13 00:00:00.000000                    Yes
# 2362                     2020-07-13 00:00:00.000000                    Yes
# 2703                     2021-07-06 00:00:00.000000                    Yes
# 2705                     2021-07-06 00:00:00.000000                    Yes
#
#                          condition_source_concept_id
# condition_occurrence_id
# 324                                           378253
# 325                                           378253
# 789                                           378253
# 790                                           378253
# 1814                                          378253
# 1815                                          378253
# 2361                                          378253
# 2362                                          378253
# 2703                                          378253
# 2705                                          378253
# 2022-03-17 10:53:20 - ExampleDataset - INFO - called save_dateframe but outputs are not defined. save_files: True
# 2022-03-17 10:53:20 - ExampleDataset - INFO - finalised condition_occurrence on iteration 0 producing 262180 rows from 12 tables
# 2022-03-17 10:53:20 - LocalDataCollection - INFO - Getting next chunk of data
# 2022-03-17 10:53:20 - LocalDataCollection - INFO - All input files for this object have now been used.
# 2022-03-17 10:53:20 - LocalDataCollection - INFO - resetting used bricks
# 2022-03-17 10:53:20 - ExampleDataset - INFO - for drug_exposure: found 5 objects
# 2022-03-17 10:53:20 - ExampleDataset - INFO - working on drug_exposure
# 2022-03-17 10:53:20 - ExampleDataset - INFO - starting on drug_exposure_0
# 2022-03-17 10:53:20 - LocalDataCollection - INFO - Retrieving initial dataframe for 'Vaccinations.csv' for the first time
# 2022-03-17 10:53:20 - DrugExposure - WARNING - Requiring non-null values in drug_concept_id removed 47496 rows, leaving 24504 rows.
# 2022-03-17 10:53:20 - DrugExposure - WARNING - Requiring non-null values in drug_exposure_start_datetime removed 20 rows, leaving 24484 rows.
# 2022-03-17 10:53:20 - DrugExposure - INFO - Automatically formatting data columns.
# 2022-03-17 10:53:21 - DrugExposure - INFO - created df (0x13812b520)[drug_exposure_0]
# 2022-03-17 10:53:21 - ExampleDataset - INFO - finished drug_exposure_0 (0x13812b520) ... 1/5 completed, 24484 rows
# 2022-03-17 10:53:22 - ExampleDataset - ERROR - There are person_ids in this table that are not in the output person table!
# 2022-03-17 10:53:22 - ExampleDataset - ERROR - Either they are not in the original data, or while creating the person table,
# 2022-03-17 10:53:22 - ExampleDataset - ERROR - studies have been removed due to lack of required fields, such as birthdate.
# 2022-03-17 10:53:22 - ExampleDataset - ERROR - 24359/24484 were good, 125 studies are removed.
# 2022-03-17 10:53:22 - ExampleDataset - INFO - starting on drug_exposure_1
# 2022-03-17 10:53:22 - DrugExposure - WARNING - Requiring non-null values in drug_concept_id removed 48339 rows, leaving 23661 rows.
# 2022-03-17 10:53:22 - DrugExposure - WARNING - Requiring non-null values in drug_exposure_start_datetime removed 26 rows, leaving 23635 rows.
# 2022-03-17 10:53:22 - DrugExposure - INFO - Automatically formatting data columns.
# 2022-03-17 10:53:23 - DrugExposure - INFO - created df (0x13a401a30)[drug_exposure_1]
# 2022-03-17 10:53:23 - ExampleDataset - INFO - finished drug_exposure_1 (0x13a401a30) ... 2/5 completed, 23635 rows
# 2022-03-17 10:53:23 - ExampleDataset - ERROR - There are person_ids in this table that are not in the output person table!
# 2022-03-17 10:53:23 - ExampleDataset - ERROR - Either they are not in the original data, or while creating the person table,
# 2022-03-17 10:53:23 - ExampleDataset - ERROR - studies have been removed due to lack of required fields, such as birthdate.
# 2022-03-17 10:53:23 - ExampleDataset - ERROR - 23505/23635 were good, 130 studies are removed.
# 2022-03-17 10:53:23 - ExampleDataset - INFO - starting on drug_exposure_2
# 2022-03-17 10:53:23 - DrugExposure - WARNING - Requiring non-null values in drug_concept_id removed 48165 rows, leaving 23835 rows.
# 2022-03-17 10:53:23 - DrugExposure - WARNING - Requiring non-null values in drug_exposure_start_datetime removed 29 rows, leaving 23806 rows.
# 2022-03-17 10:53:23 - DrugExposure - INFO - Automatically formatting data columns.
# 2022-03-17 10:53:24 - DrugExposure - INFO - created df (0x13af8d190)[drug_exposure_2]
# 2022-03-17 10:53:25 - ExampleDataset - INFO - finished drug_exposure_2 (0x13af8d190) ... 3/5 completed, 23806 rows
# 2022-03-17 10:53:25 - ExampleDataset - ERROR - There are person_ids in this table that are not in the output person table!
# 2022-03-17 10:53:25 - ExampleDataset - ERROR - Either they are not in the original data, or while creating the person table,
# 2022-03-17 10:53:25 - ExampleDataset - ERROR - studies have been removed due to lack of required fields, such as birthdate.
# 2022-03-17 10:53:25 - ExampleDataset - ERROR - 23697/23806 were good, 109 studies are removed.
# 2022-03-17 10:53:25 - ExampleDataset - INFO - starting on drug_exposure_3
# 2022-03-17 10:53:25 - DrugExposure - WARNING - Requiring non-null values in drug_concept_id removed 47496 rows, leaving 24504 rows.
# 2022-03-17 10:53:25 - DrugExposure - WARNING - Requiring non-null values in drug_exposure_start_datetime removed 20 rows, leaving 24484 rows.
# 2022-03-17 10:53:25 - DrugExposure - INFO - Automatically formatting data columns.
# 2022-03-17 10:53:26 - DrugExposure - INFO - created df (0x13812b3d0)[drug_exposure_3]
# 2022-03-17 10:53:26 - ExampleDataset - INFO - finished drug_exposure_3 (0x13812b3d0) ... 4/5 completed, 24484 rows
# 2022-03-17 10:53:26 - ExampleDataset - ERROR - There are person_ids in this table that are not in the output person table!
# 2022-03-17 10:53:26 - ExampleDataset - ERROR - Either they are not in the original data, or while creating the person table,
# 2022-03-17 10:53:26 - ExampleDataset - ERROR - studies have been removed due to lack of required fields, such as birthdate.
# 2022-03-17 10:53:26 - ExampleDataset - ERROR - 24359/24484 were good, 125 studies are removed.
# 2022-03-17 10:53:26 - ExampleDataset - INFO - starting on drug_exposure_4
# 2022-03-17 10:53:27 - DrugExposure - WARNING - Requiring non-null values in drug_concept_id removed 48165 rows, leaving 23835 rows.
# 2022-03-17 10:53:27 - DrugExposure - WARNING - Requiring non-null values in drug_exposure_start_datetime removed 29 rows, leaving 23806 rows.
# 2022-03-17 10:53:27 - DrugExposure - INFO - Automatically formatting data columns.
# 2022-03-17 10:53:27 - DrugExposure - INFO - created df (0x13af8d9a0)[drug_exposure_4]
# 2022-03-17 10:53:28 - ExampleDataset - INFO - finished drug_exposure_4 (0x13af8d9a0) ... 5/5 completed, 23806 rows
# 2022-03-17 10:53:28 - ExampleDataset - ERROR - There are person_ids in this table that are not in the output person table!
# 2022-03-17 10:53:28 - ExampleDataset - ERROR - Either they are not in the original data, or while creating the person table,
# 2022-03-17 10:53:28 - ExampleDataset - ERROR - studies have been removed due to lack of required fields, such as birthdate.
# 2022-03-17 10:53:28 - ExampleDataset - ERROR - 23697/23806 were good, 109 studies are removed.
# 2022-03-17 10:53:29 - ExampleDataset - INFO - called save_dateframe but outputs are not defined. save_files: True
# 2022-03-17 10:53:29 - ExampleDataset - INFO - finalised drug_exposure on iteration 0 producing 119617 rows from 5 tables
# 2022-03-17 10:53:29 - LocalDataCollection - INFO - Getting next chunk of data
# 2022-03-17 10:53:29 - LocalDataCollection - INFO - All input files for this object have now been used.
# 2022-03-17 10:53:29 - LocalDataCollection - INFO - resetting used bricks
# 2022-03-17 10:53:29 - ExampleDataset - INFO - for observation: found 4 objects
# 2022-03-17 10:53:29 - ExampleDataset - INFO - working on observation
# 2022-03-17 10:53:29 - ExampleDataset - INFO - starting on observation_0
# 2022-03-17 10:53:29 - LocalDataCollection - INFO - Retrieving initial dataframe for 'Serology.csv' for the first time
# 2022-03-17 10:53:29 - Observation - INFO - Automatically formatting data columns.
# 2022-03-17 10:53:30 - Observation - INFO - created df (0x13bd0bdf0)[observation_0]
# 2022-03-17 10:53:30 - ExampleDataset - INFO - finished observation_0 (0x13bd0bdf0) ... 1/4 completed, 41140 rows
# 2022-03-17 10:53:30 - ExampleDataset - ERROR - There are person_ids in this table that are not in the output person table!
# 2022-03-17 10:53:30 - ExampleDataset - ERROR - Either they are not in the original data, or while creating the person table,
# 2022-03-17 10:53:30 - ExampleDataset - ERROR - studies have been removed due to lack of required fields, such as birthdate.
# 2022-03-17 10:53:30 - ExampleDataset - ERROR - 40953/41140 were good, 187 studies are removed.
# 2022-03-17 10:53:30 - ExampleDataset - INFO - starting on observation_1
# 2022-03-17 10:53:30 - LocalDataCollection - INFO - Retrieving initial dataframe for 'Hospital_Visit.csv' for the first time
# 2022-03-17 10:53:30 - Observation - WARNING - Requiring non-null values in observation_concept_id removed 96170 rows, leaving 23830 rows.
# 2022-03-17 10:53:30 - Observation - INFO - Automatically formatting data columns.
# 2022-03-17 10:53:31 - Observation - INFO - created df (0x13bd0b5b0)[observation_1]
# 2022-03-17 10:53:31 - ExampleDataset - INFO - finished observation_1 (0x13bd0b5b0) ... 2/4 completed, 23830 rows
# 2022-03-17 10:53:31 - ExampleDataset - ERROR - There are person_ids in this table that are not in the output person table!
# 2022-03-17 10:53:31 - ExampleDataset - ERROR - Either they are not in the original data, or while creating the person table,
# 2022-03-17 10:53:31 - ExampleDataset - ERROR - studies have been removed due to lack of required fields, such as birthdate.
# 2022-03-17 10:53:31 - ExampleDataset - ERROR - 23714/23830 were good, 116 studies are removed.
# 2022-03-17 10:53:31 - ExampleDataset - INFO - starting on observation_2
# 2022-03-17 10:53:31 - Observation - WARNING - Requiring non-null values in observation_concept_id removed 101943 rows, leaving 18057 rows.
# 2022-03-17 10:53:31 - Observation - INFO - Automatically formatting data columns.
# 2022-03-17 10:53:32 - Observation - INFO - created df (0x13af8d7f0)[observation_2]
# 2022-03-17 10:53:32 - ExampleDataset - INFO - finished observation_2 (0x13af8d7f0) ... 3/4 completed, 18057 rows
# 2022-03-17 10:53:32 - ExampleDataset - ERROR - There are person_ids in this table that are not in the output person table!
# 2022-03-17 10:53:32 - ExampleDataset - ERROR - Either they are not in the original data, or while creating the person table,
# 2022-03-17 10:53:32 - ExampleDataset - ERROR - studies have been removed due to lack of required fields, such as birthdate.
# 2022-03-17 10:53:32 - ExampleDataset - ERROR - 17967/18057 were good, 90 studies are removed.
# 2022-03-17 10:53:32 - ExampleDataset - INFO - starting on observation_3
# 2022-03-17 10:53:33 - Observation - WARNING - Requiring non-null values in observation_concept_id removed 83761 rows, leaving 36239 rows.
# 2022-03-17 10:53:33 - Observation - INFO - Automatically formatting data columns.
# 2022-03-17 10:53:33 - Observation - INFO - created df (0x13c67e160)[observation_3]
# 2022-03-17 10:53:34 - ExampleDataset - INFO - finished observation_3 (0x13c67e160) ... 4/4 completed, 36239 rows
# 2022-03-17 10:53:34 - ExampleDataset - ERROR - There are person_ids in this table that are not in the output person table!
# 2022-03-17 10:53:34 - ExampleDataset - ERROR - Either they are not in the original data, or while creating the person table,
# 2022-03-17 10:53:34 - ExampleDataset - ERROR - studies have been removed due to lack of required fields, such as birthdate.
# 2022-03-17 10:53:34 - ExampleDataset - ERROR - 36056/36239 were good, 183 studies are removed.
# 2022-03-17 10:53:34 - ExampleDataset - ERROR - Removed 7 row(s) due to duplicates found when merging observation
# 2022-03-17 10:53:34 - ExampleDataset - WARNING - Example duplicates...
# 2022-03-17 10:53:34 - ExampleDataset - WARNING -                 person_id  observation_concept_id observation_date  \
# observation_id
# 43692             11374.0                 4059317       2021-01-04
# 43693             11374.0                 4059317       2021-01-04
# 61370              4782.0                 4059317       2019-11-09
# 61371              4782.0                 4059317       2019-11-09
# 82699              5601.0                40757663       2020-07-19
# 82700              5601.0                40757663       2020-07-19
# 104534            83715.0                40757663       2019-07-24
# 104535            83715.0                40757663       2019-07-24
# 110501            43509.0                40757663       2020-05-17
# 110502            43509.0                40757663       2020-05-17
#
#                       observation_datetime observation_source_value  \
# observation_id
# 43692           2021-01-04 00:00:00.000000             Heart Attack
# 43693           2021-01-04 00:00:00.000000             Heart Attack
# 61370           2019-11-09 00:00:00.000000             Heart Attack
# 61371           2019-11-09 00:00:00.000000             Heart Attack
# 82699           2020-07-19 00:00:00.000000                   Cancer
# 82700           2020-07-19 00:00:00.000000                   Cancer
# 104534          2019-07-24 00:00:00.000000                   Cancer
# 104535          2019-07-24 00:00:00.000000                   Cancer
# 110501          2020-05-17 00:00:00.000000                   Cancer
# 110502          2020-05-17 00:00:00.000000                   Cancer
#
#                 observation_source_concept_id
# observation_id
# 43692                                 4059317
# 43693                                 4059317
# 61370                                 4059317
# 61371                                 4059317
# 82699                                40757663
# 82700                                40757663
# 104534                               40757663
# 104535                               40757663
# 110501                               40757663
# 110502                               40757663
# 2022-03-17 10:53:34 - ExampleDataset - INFO - called save_dateframe but outputs are not defined. save_files: True
# 2022-03-17 10:53:34 - ExampleDataset - INFO - finalised observation on iteration 0 producing 118690 rows from 4 tables
# 2022-03-17 10:53:34 - LocalDataCollection - INFO - Getting next chunk of data
# 2022-03-17 10:53:34 - LocalDataCollection - INFO - All input files for this object have now been used.

# %%
instance.keys()
# Out:
# dict_keys(['person', 'condition_occurrence', 'drug_exposure', 'observation'])

# %%
instance['observation'].dropna(axis=1)
# Out:
#                 person_id  observation_concept_id observation_date  \
# observation_id
# 1                 36796.0                 4288455       2021-10-22
# 2                 17453.0                 4288455       2020-10-26
# 3                 58448.0                 4288455       2021-02-03
# 4                 83263.0                 4288455       2020-04-05
# 5                  6544.0                 4288455       2022-11-19
# ...                   ...                     ...              ...
# 118869            54967.0                40757663       2019-05-10
# 118870            54969.0                40757663       2020-01-09
# 118871            54969.0                40757663       2021-04-28
# 118872            54973.0                40757663       2019-01-29
# 118873            99479.0                40757663       2021-01-22
#
#                       observation_datetime observation_source_value  \
# observation_id
# 1               2021-10-22 00:00:00.000000       57.527969992111224
# 2               2020-10-26 00:00:00.000000       1.2722186060345093
# 3               2021-02-03 00:00:00.000000         88.1524834152799
# 4               2020-04-05 00:00:00.000000        54.55584411002554
# 5               2022-11-19 00:00:00.000000       29.283913796854904
# ...                                    ...                      ...
# 118869          2019-05-10 00:00:00.000000                   Cancer
# 118870          2020-01-09 00:00:00.000000                   Cancer
# 118871          2021-04-28 00:00:00.000000                   Cancer
# 118872          2019-01-29 00:00:00.000000                   Cancer
# 118873          2021-01-22 00:00:00.000000                   Cancer
#
#                 observation_source_concept_id
# observation_id
# 1                                     4288455
# 2                                     4288455
# 3                                     4288455
# 4                                     4288455
# 5                                     4288455
# ...                                       ...
# 118869                               40757663
# 118870                               40757663
# 118871                               40757663
# 118872                               40757663
# 118873                               40757663
#
# [118683 rows x 6 columns]

# %% [markdown]
# ## Manually edited
#
# By generating a python class from the rules files, you can manually edit the python file setting up i/o as well as making some edits to the various tables. Once done, it could simple be run as a python file:
# ```
# python  ExampleDatasetModified.py
# ```

# %%
# %load ExampleDatasetModified.py
from coconnect.cdm import define_person, define_condition_occurrence, define_visit_occurrence, define_measurement, define_observation, define_drug_exposure
from coconnect.cdm import CommonDataModel
from coconnect.tools import load_csv,create_csv_store
import json
import glob
import pandas as pd

class ExampleDatasetModified(CommonDataModel):
    
    def __init__(self,**kwargs):
        """ 
        initialise the inputs and setup indexing 
        """
        inputs = load_csv(glob.glob('../data/part1/*'))
        outputs = create_csv_store(output_folder="./data_tests/",
                                                   sep="\t",
                                                   write_separate=True,
                                                   write_mode='w')
        
        super().__init__(inputs=inputs,outputs=outputs,**kwargs)
        self.process()
    
    @define_person
    def person_0(self):
        """
        Create CDM object for person
        """
        self.birth_datetime.series = self.inputs["Demographics.csv"]["Age"]
        self.gender_concept_id.series = self.inputs["Demographics.csv"]["Sex"]
        self.gender_source_concept_id.series = self.inputs["Demographics.csv"]["Sex"]
        self.gender_source_value.series = self.inputs["Demographics.csv"]["Sex"]
        self.person_id.series = self.inputs["Demographics.csv"]["ID"]
        
        # --- insert field operations --- 
        self.birth_datetime.series = self.tools.get_datetime_from_age(self.birth_datetime.series)
        
        # --- insert term mapping --- 
        self.gender_concept_id.series = self.gender_concept_id.series.map(
            {
                "Male": 8507,
                "Female": 8532
            }
        )

    @define_observation
    def observation_0(self):
        """
        Create CDM object for observation
        """

        def convert_igg(x):
            """
            A custom function to convert the IgG into g/L
            """
            
            #example of a dataset where the assay has been recalibrated after a certain date
            #therefore you might need to do some conversion based upon the date
            factor = 1.2 if x['Date'].year < 2021 else 1
            
            #apply a factor to convert to g/L
            factor = factor * 10
            
            #return the modified IgG value
            return float(x['IgG'])*factor
        
        #save the source value of the IgG
        self.observation_source_value.series = self.inputs["Serology.csv"]["IgG"]

        #convert the date into a datetime object
        self.inputs["Serology.csv"]["Date"] =  pd.to_datetime(self.inputs["Serology.csv"]["Date"])
        
        #recalculate the IgG based upon a custom function
        self.inputs["Serology.csv"]["IgG"] = self.inputs["Serology.csv"].apply(lambda x: convert_igg(x),axis=1)
        #set the output units
        self.inputs["Serology.csv"]["Units"] = 'g/L'
        
        #set additional columns we did not have before...
        self.unit_source_value.series = self.inputs["Serology.csv"]["Units"]
        self.value_as_number.series = self.inputs["Serology.csv"]["IgG"]

        
        self.observation_concept_id.series = self.inputs["Serology.csv"]["IgG"]
        self.observation_datetime.series = self.inputs["Serology.csv"]["Date"]
        self.observation_source_concept_id.series = self.inputs["Serology.csv"]["IgG"]
        self.person_id.series = self.inputs["Serology.csv"]["ID"]

        
        # --- insert term mapping --- 
        self.observation_concept_id.series = self.tools.make_scalar(self.observation_concept_id.series,4288455)
        self.observation_source_concept_id.series = self.tools.make_scalar(self.observation_source_concept_id.series,4288455)

# %%
instance = ExampleDatasetModified()
instance
# Out:
# 2022-03-16 14:46:24 - LocalDataCollection - INFO - DataCollection Object Created
# 2022-03-16 14:46:24 - LocalDataCollection - INFO - Registering  Symptoms.csv [<coconnect.io.common.DataBrick object at 0x12e49d8b0>]
# 2022-03-16 14:46:24 - LocalDataCollection - INFO - Registering  Blood_Test.csv [<coconnect.io.common.DataBrick object at 0x12e49da30>]
# 2022-03-16 14:46:24 - LocalDataCollection - INFO - Registering  Serology.csv [<coconnect.io.common.DataBrick object at 0x12e49dca0>]
# 2022-03-16 14:46:24 - LocalDataCollection - INFO - Registering  GP_Records.csv [<coconnect.io.common.DataBrick object at 0x12e49d7f0>]
# 2022-03-16 14:46:24 - LocalDataCollection - INFO - Registering  Vaccinations.csv [<coconnect.io.common.DataBrick object at 0x12e49d820>]
# 2022-03-16 14:46:25 - LocalDataCollection - INFO - Registering  Hospital_Visit.csv [<coconnect.io.common.DataBrick object at 0x12e49dd00>]
# 2022-03-16 14:46:25 - LocalDataCollection - INFO - Registering  pks.csv [<coconnect.io.common.DataBrick object at 0x12d9ad880>]
# 2022-03-16 14:46:25 - LocalDataCollection - INFO - Registering  Demographics.csv [<coconnect.io.common.DataBrick object at 0x12d9ad5e0>]
# 2022-03-16 14:46:25 - LocalDataCollection - INFO - DataCollection Object Created
# 2022-03-16 14:46:25 - ExampleDatasetModified - INFO - CommonDataModel (5.3.1) created with co-connect-tools version 0.0.0
# 2022-03-16 14:46:25 - ExampleDatasetModified - INFO - Running with an DataCollection object
# 2022-03-16 14:46:25 - ExampleDatasetModified - INFO - Turning on automatic cdm column filling
# 2022-03-16 14:46:25 - ExampleDatasetModified - INFO - Added observation_0 of type observation
# 2022-03-16 14:46:25 - ExampleDatasetModified - INFO - Added person_0 of type person
# 2022-03-16 14:46:25 - ExampleDatasetModified - INFO - Starting processing in order: ['person', 'observation']
# 2022-03-16 14:46:25 - ExampleDatasetModified - INFO - Number of objects to process for each table...
# {
#       "observation": 1,
#       "person": 1
# }
# 2022-03-16 14:46:25 - ExampleDatasetModified - INFO - for person: found 1 object
# 2022-03-16 14:46:25 - ExampleDatasetModified - INFO - working on person
# 2022-03-16 14:46:25 - ExampleDatasetModified - INFO - starting on person_0
# 2022-03-16 14:46:25 - LocalDataCollection - INFO - Retrieving initial dataframe for 'Demographics.csv' for the first time
# 2022-03-16 14:46:28 - Person - WARNING - Requiring non-null values in gender_concept_id removed 519 rows, leaving 99481 rows.
# 2022-03-16 14:46:28 - Person - INFO - Automatically formatting data columns.
# 2022-03-16 14:46:30 - Person - INFO - created df (0x1320a6790)[person_0]
# 2022-03-16 14:46:30 - ExampleDatasetModified - INFO - finished person_0 (0x1320a6790) ... 1/1 completed, 99481 rows
# 2022-03-16 14:46:30 - LocalDataCollection - INFO - saving person_ids.0x109389ee0.2022-03-16T144630 to ./data_tests//person_ids.0x109389ee0.2022-03-16T144630.tsv
# 2022-03-16 14:46:30 - LocalDataCollection - INFO - finished save to file
# 2022-03-16 14:46:30 - ExampleDatasetModified - INFO - saving dataframe (0x109389ee0) to <coconnect.io.plugins.local.LocalDataCollection object at 0x12e49d520>
# 2022-03-16 14:46:30 - LocalDataCollection - INFO - saving person.0x109389ee0.2022-03-16T144630 to ./data_tests//person.0x109389ee0.2022-03-16T144630.tsv
# 2022-03-16 14:46:31 - LocalDataCollection - INFO - finished save to file
# 2022-03-16 14:46:31 - ExampleDatasetModified - INFO - finalised person on iteration 0 producing 99481 rows from 1 tables
# 2022-03-16 14:46:31 - LocalDataCollection - INFO - Getting next chunk of data
# 2022-03-16 14:46:31 - LocalDataCollection - INFO - All input files for this object have now been used.
# 2022-03-16 14:46:31 - LocalDataCollection - INFO - resetting used bricks
# 2022-03-16 14:46:31 - ExampleDatasetModified - INFO - for observation: found 1 object
# 2022-03-16 14:46:31 - ExampleDatasetModified - INFO - working on observation
# 2022-03-16 14:46:31 - ExampleDatasetModified - INFO - starting on observation_0
# 2022-03-16 14:46:31 - LocalDataCollection - INFO - Retrieving initial dataframe for 'Serology.csv' for the first time
# 2022-03-16 14:46:33 - Observation - INFO - Automatically formatting data columns.
# 2022-03-16 14:46:34 - Observation - INFO - created df (0x13394c250)[observation_0]
# 2022-03-16 14:46:34 - ExampleDatasetModified - INFO - finished observation_0 (0x13394c250) ... 1/1 completed, 41140 rows
# 2022-03-16 14:46:34 - ExampleDatasetModified - ERROR - There are person_ids in this table that are not in the output person table!
# 2022-03-16 14:46:34 - ExampleDatasetModified - ERROR - Either they are not in the original data, or while creating the person table,
# 2022-03-16 14:46:34 - ExampleDatasetModified - ERROR - studies have been removed due to lack of required fields, such as birthdate.
# 2022-03-16 14:46:34 - ExampleDatasetModified - ERROR - 40953/41140 were good, 187 studies are removed.
# 2022-03-16 14:46:35 - ExampleDatasetModified - INFO - saving dataframe (0x12e4b2f40) to <coconnect.io.plugins.local.LocalDataCollection object at 0x12e49d520>
# 2022-03-16 14:46:35 - LocalDataCollection - INFO - saving observation.0x12e4b2f40.2022-03-16T144635 to ./data_tests//observation.0x12e4b2f40.2022-03-16T144635.tsv
# 2022-03-16 14:46:35 - LocalDataCollection - INFO - finished save to file
# 2022-03-16 14:46:35 - ExampleDatasetModified - INFO - finalised observation on iteration 0 producing 40953 rows from 1 tables
# 2022-03-16 14:46:35 - LocalDataCollection - INFO - Getting next chunk of data
# 2022-03-16 14:46:35 - LocalDataCollection - INFO - All input files for this object have now been used.

# %%
instance.keys()
# Out:
# dict_keys(['person', 'observation'])

# %%
instance['observation'].dropna(axis=1)
# Out:
#                 person_id  observation_concept_id observation_date  \
# observation_id
# 1                   66578                 4288455       2021-10-22
# 2                   31668                 4288455       2020-10-26
# 3                    7717                 4288455       2021-02-03
# 4                   63190                 4288455       2020-04-05
# 5                   11876                 4288455       2022-11-19
# ...                   ...                     ...              ...
# 41136               34692                 4288455       2021-04-10
# 41137               14922                 4288455       2021-03-16
# 41138               61035                 4288455       2021-05-25
# 41139               12653                 4288455       2021-01-22
# 41140               67439                 4288455       2022-03-06
#
#                       observation_datetime  value_as_number  \
# observation_id
# 1               2021-10-22 00:00:00.000000         57.52797
# 2               2020-10-26 00:00:00.000000         1.526662
# 3               2021-02-03 00:00:00.000000        88.152483
# 4               2020-04-05 00:00:00.000000        65.467013
# 5               2022-11-19 00:00:00.000000        29.283914
# ...                                    ...              ...
# 41136           2021-04-10 00:00:00.000000        44.055308
# 41137           2021-03-16 00:00:00.000000        68.023008
# 41138           2021-05-25 00:00:00.000000        20.857946
# 41139           2021-01-22 00:00:00.000000        22.646181
# 41140           2022-03-06 00:00:00.000000        23.424595
#
#                observation_source_value  observation_source_concept_id  \
# observation_id
# 1                    57.527969992111224                        4288455
# 2                    1.2722186060345093                        4288455
# 3                      88.1524834152799                        4288455
# 4                     54.55584411002554                        4288455
# 5                    29.283913796854904                        4288455
# ...                                 ...                            ...
# 41136                44.055307552316364                        4288455
# 41137                 68.02300798516276                        4288455
# 41138                20.857945874128763                        4288455
# 41139                 22.64618089045576                        4288455
# 41140                23.424594953707338                        4288455
#
#                unit_source_value
# observation_id
# 1                            g/L
# 2                            g/L
# 3                            g/L
# 4                            g/L
# 5                            g/L
# ...                          ...
# 41136                        g/L
# 41137                        g/L
# 41138                        g/L
# 41139                        g/L
# 41140                        g/L
#
# [40953 rows x 8 columns]
