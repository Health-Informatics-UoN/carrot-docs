# %% [markdown]
# This work book shows how different types of input data can be manipulated manually and loaded into `pandas` dataframes , which are subsequently used by the `CommonDataModel`
#
# Importing packages:

# %%
import coconnect
import glob
import pandas as pd
import os
from sqlalchemy import create_engine

# %% [markdown]
# ## CSV Files
#
# Create a map between the csv filename and a `pandas` dataframe, loaded from the csv
#
# __note__: `iterator=True` tells pandas to not read the data into memory, but setup a `parsers.TextFileReader`
#           specifying `chunksize=<value>` will also return an iterator, allowing for easy looping over data chunks

# %%
df_map = {
            os.path.basename(x):pd.read_csv(x,iterator=True) 
            for x in glob.glob('../data/part1/*.csv')
         }
df_map
# Out:
# {'Symptoms.csv': <pandas.io.parsers.TextFileReader at 0x10e4a9880>,
#  'Blood_Test.csv': <pandas.io.parsers.TextFileReader at 0x10d766550>,
#  'Serology.csv': <pandas.io.parsers.TextFileReader at 0x10a9b2370>,
#  'GP_Records.csv': <pandas.io.parsers.TextFileReader at 0x10a9e3520>,
#  'Vaccinations.csv': <pandas.io.parsers.TextFileReader at 0x10e4fac40>,
#  'Hospital_Visit.csv': <pandas.io.parsers.TextFileReader at 0x10e4faeb0>,
#  'Demographics.csv': <pandas.io.parsers.TextFileReader at 0x10e4fac70>}

# %% [markdown]
# Create a co-connect `LocalDataCollection` object to store the dataframes

# %%
csv_inputs = coconnect.io.LocalDataCollection()
csv_inputs.load_input_dataframe(df_map)
csv_inputs
# Out:
# 2022-03-16 16:33:17 - LocalDataCollection - INFO - DataCollection Object Created
# 2022-03-16 16:33:17 - LocalDataCollection - INFO - Registering  Symptoms.csv [<coconnect.io.common.DataBrick object at 0x10a9e3cd0>]
# 2022-03-16 16:33:17 - LocalDataCollection - INFO - Registering  Blood_Test.csv [<coconnect.io.common.DataBrick object at 0x10a9e3a00>]
# 2022-03-16 16:33:17 - LocalDataCollection - INFO - Registering  Serology.csv [<coconnect.io.common.DataBrick object at 0x10a9e3c40>]
# 2022-03-16 16:33:17 - LocalDataCollection - INFO - Registering  GP_Records.csv [<coconnect.io.common.DataBrick object at 0x10a9e3a90>]
# 2022-03-16 16:33:17 - LocalDataCollection - INFO - Registering  Vaccinations.csv [<coconnect.io.common.DataBrick object at 0x10e5194c0>]
# 2022-03-16 16:33:17 - LocalDataCollection - INFO - Registering  Hospital_Visit.csv [<coconnect.io.common.DataBrick object at 0x10e5194f0>]
# 2022-03-16 16:33:17 - LocalDataCollection - INFO - Registering  Demographics.csv [<coconnect.io.common.DataBrick object at 0x10e519430>]

# %% [markdown]
# Check to see what data has been loaded:

# %%
csv_inputs.keys()
# Out:
# dict_keys(['Symptoms.csv', 'Blood_Test.csv', 'Serology.csv', 'GP_Records.csv', 'Vaccinations.csv', 'Hospital_Visit.csv', 'Demographics.csv'])

# %% [markdown]
# ## SQL
#
# The following shows how these objects can be used to write the csv files from the input collection to a SQL database.

# %%
sql_store = coconnect.io.SqlDataCollection(connection_string="postgresql://localhost:5432/ExampleCOVID19DataSet",
                                          drop_existing=True)
sql_store
# Out:
# 2022-03-16 16:33:17 - SqlDataCollection - INFO - DataCollection Object Created
# 2022-03-16 16:33:18 - SqlDataCollection - INFO - Engine(postgresql://localhost:5432/ExampleCOVID19DataSet)

# %% [markdown]
# Loop over all the inputs, get a loaded dataframe from the input collections, and use the sql store to write the dataframe to the SQL database

# %%
for name in csv_inputs.keys():
    df = csv_inputs[name]
    name = name.split(".")[0]
    sql_store.write(name,df)
# Out:
# 2022-03-16 16:33:18 - LocalDataCollection - INFO - Retrieving initial dataframe for 'Symptoms.csv' for the first time
# 2022-03-16 16:33:18 - SqlDataCollection - INFO - updating Symptoms in Engine(postgresql://localhost:5432/ExampleCOVID19DataSet)
# 2022-03-16 16:33:27 - SqlDataCollection - INFO - finished save to psql
# 2022-03-16 16:33:27 - LocalDataCollection - INFO - Retrieving initial dataframe for 'Blood_Test.csv' for the first time
# 2022-03-16 16:33:27 - SqlDataCollection - INFO - updating Blood_Test in Engine(postgresql://localhost:5432/ExampleCOVID19DataSet)
# 2022-03-16 16:33:44 - SqlDataCollection - INFO - finished save to psql
# 2022-03-16 16:33:44 - LocalDataCollection - INFO - Retrieving initial dataframe for 'Serology.csv' for the first time
# 2022-03-16 16:33:44 - SqlDataCollection - INFO - updating Serology in Engine(postgresql://localhost:5432/ExampleCOVID19DataSet)
# 2022-03-16 16:33:56 - SqlDataCollection - INFO - finished save to psql
# 2022-03-16 16:33:56 - LocalDataCollection - INFO - Retrieving initial dataframe for 'GP_Records.csv' for the first time
# 2022-03-16 16:33:56 - SqlDataCollection - INFO - updating GP_Records in Engine(postgresql://localhost:5432/ExampleCOVID19DataSet)
# 2022-03-16 16:35:20 - SqlDataCollection - INFO - finished save to psql
# 2022-03-16 16:35:20 - LocalDataCollection - INFO - Retrieving initial dataframe for 'Vaccinations.csv' for the first time
# 2022-03-16 16:35:20 - SqlDataCollection - INFO - updating Vaccinations in Engine(postgresql://localhost:5432/ExampleCOVID19DataSet)
# 2022-03-16 16:35:56 - SqlDataCollection - INFO - finished save to psql
# 2022-03-16 16:35:56 - LocalDataCollection - INFO - Retrieving initial dataframe for 'Hospital_Visit.csv' for the first time
# 2022-03-16 16:35:56 - SqlDataCollection - INFO - updating Hospital_Visit in Engine(postgresql://localhost:5432/ExampleCOVID19DataSet)
# 2022-03-16 16:36:50 - SqlDataCollection - INFO - finished save to psql
# 2022-03-16 16:36:50 - LocalDataCollection - INFO - Retrieving initial dataframe for 'Demographics.csv' for the first time
# 2022-03-16 16:36:50 - SqlDataCollection - INFO - updating Demographics in Engine(postgresql://localhost:5432/ExampleCOVID19DataSet)
# 2022-03-16 16:37:43 - SqlDataCollection - INFO - finished save to psql

# %% [markdown]
# Now we can used pandas to test the SQL database we created, and load in some filtered data:

# %%
connection_string="postgresql://localhost:5432/ExampleCOVID19DataSet"
engine = create_engine(connection_string)

# %% [markdown]
# Retrieve a filtered pandas dataframe from the SQL connection

# %%
df_demo = pd.read_sql('SELECT * FROM "Demographics" WHERE "IMD" = 5 LIMIT 1000;',con=engine)
df_demo
# Out:
#          ID   Age     Sex Ethnicity  IMD
# 0       pk1  73.0    Male     Black    5
# 1       pk2  65.0  Female     Black    5
# 2      pk11  58.0    Male     White    5
# 3      pk15  55.0  Female     White    5
# 4      pk16  42.0  Female     White    5
# ..      ...   ...     ...       ...  ...
# 995  pk4155  84.0    Male     White    5
# 996  pk4156  82.0  Female     White    5
# 997  pk4161  63.0    Male     White    5
# 998  pk4164  61.0  Female     Black    5
# 999  pk4165  48.0  Female     White    5
#
# [1000 rows x 5 columns]

# %% [markdown]
# Use a more complex SQL command to filter the Serology table based on information in the demographics table, creating a pandas dataframe object.

# %%
sql_command = r'''
SELECT 
    * 
FROM "Serology" 
WHERE "ID" in (
    SELECT 
        "ID" 
    FROM "Demographics" 
    WHERE "IMD" = 5 LIMIT 1000
    )
'''
df_serology = pd.read_sql(sql_command,con=engine)
df_serology
# Out:
#          ID        Date        IgG
# 0    pk3262  2020-03-29  40.481863
# 1    pk1096  2022-07-26   9.057812
# 2    pk1249  2019-10-15   6.761957
# 3    pk2090  2022-01-08   1.981973
# 4     pk195  2022-04-12   1.441420
# ..      ...         ...        ...
# 358  pk1066  2023-03-17  66.714910
# 359   pk259  2020-03-09  31.556371
# 360  pk1873  2020-11-09  15.658885
# 361  pk1491  2019-08-26   6.093198
# 362  pk2380  2021-08-15   1.877754
#
# [363 rows x 3 columns]

# %% [markdown]
# Build a new LocalDataCollection from the dataframes pulled from SQL and loaded in memory:

# %%
sql_inputs = coconnect.io.LocalDataCollection()
sql_inputs.load_input_dataframe({'Serology.csv':df_serology,'Demographics.csv':df_demo})
sql_inputs
# Out:
# 2022-03-16 16:37:43 - LocalDataCollection - INFO - DataCollection Object Created
# 2022-03-16 16:37:43 - LocalDataCollection - INFO - Registering  Serology.csv [<coconnect.io.common.DataBrick object at 0x10e5609a0>]
# 2022-03-16 16:37:43 - LocalDataCollection - INFO - Registering  Demographics.csv [<coconnect.io.common.DataBrick object at 0x10e519ca0>]

# %% [markdown]
# Load some rules (and remove some missing source tables, since we only are dealing with two tables, and only want to apply rules associated with them):

# %%
rules = coconnect.tools.load_json("../data/rules.json")
rules = coconnect.tools.remove_missing_sources_from_rules(rules,sql_inputs.keys())
rules
# Out:
# 2022-03-16 16:37:59 - remove_missing_sources_from_rules - WARNING - removed H/O: heart failure 3043 from rules because it was not loaded
# 2022-03-16 16:37:59 - remove_missing_sources_from_rules - WARNING - removed 2019-nCoV 3044 from rules because it was not loaded
# 2022-03-16 16:37:59 - remove_missing_sources_from_rules - WARNING - removed Cancer 3045 from rules because it was not loaded
# 2022-03-16 16:37:59 - remove_missing_sources_from_rules - WARNING - removed Headache 3028 from rules because it was not loaded
# 2022-03-16 16:37:59 - remove_missing_sources_from_rules - WARNING - removed Fatigue 3029 from rules because it was not loaded
# 2022-03-16 16:37:59 - remove_missing_sources_from_rules - WARNING - removed Dizziness 3030 from rules because it was not loaded
# 2022-03-16 16:37:59 - remove_missing_sources_from_rules - WARNING - removed Cough 3031 from rules because it was not loaded
# 2022-03-16 16:37:59 - remove_missing_sources_from_rules - WARNING - removed Fever 3032 from rules because it was not loaded
# 2022-03-16 16:37:59 - remove_missing_sources_from_rules - WARNING - removed Muscle pain 3033 from rules because it was not loaded
# 2022-03-16 16:37:59 - remove_missing_sources_from_rules - WARNING - removed Pneumonia 3042 from rules because it was not loaded
# 2022-03-16 16:37:59 - remove_missing_sources_from_rules - WARNING - removed Mental health problem 3046 from rules because it was not loaded
# 2022-03-16 16:37:59 - remove_missing_sources_from_rules - WARNING - removed Mental disorder 3047 from rules because it was not loaded
# 2022-03-16 16:37:59 - remove_missing_sources_from_rules - WARNING - removed Type 2 diabetes mellitus 3048 from rules because it was not loaded
# 2022-03-16 16:37:59 - remove_missing_sources_from_rules - WARNING - removed Ischemic heart disease 3049 from rules because it was not loaded
# 2022-03-16 16:37:59 - remove_missing_sources_from_rules - WARNING - removed Hypertensive disorder 3050 from rules because it was not loaded
# 2022-03-16 16:37:59 - remove_missing_sources_from_rules - WARNING - removed cdm table 'condition_occurrence' from rules
# 2022-03-16 16:37:59 - remove_missing_sources_from_rules - WARNING - removed COVID-19 vaccine 3034 from rules because it was not loaded
# 2022-03-16 16:37:59 - remove_missing_sources_from_rules - WARNING - removed COVID-19 vaccine 3035 from rules because it was not loaded
# 2022-03-16 16:37:59 - remove_missing_sources_from_rules - WARNING - removed COVID-19 vaccine 3036 from rules because it was not loaded
# 2022-03-16 16:37:59 - remove_missing_sources_from_rules - WARNING - removed SARS-CoV-2 (COVID-19) vaccine, mRNA-1273 0.2 MG/ML Injectable Suspension 3040 from rules because it was not loaded
# 2022-03-16 16:37:59 - remove_missing_sources_from_rules - WARNING - removed SARS-CoV-2 (COVID-19) vaccine, mRNA-BNT162b2 0.1 MG/ML Injectable Suspension 3041 from rules because it was not loaded
# 2022-03-16 16:37:59 - remove_missing_sources_from_rules - WARNING - removed cdm table 'drug_exposure' from rules
# {'metadata': {'date_created': '2022-02-11T12:22:48.465257',
#   'dataset': 'FAILED: ExampleV4'},
#  'cdm': {'person': {'MALE 3025': {'birth_datetime': {'source_table': 'Demographics.csv',
#      'source_field': 'Age',
#      'operations': ['get_datetime_from_age']},
#     'gender_concept_id': {'source_table': 'Demographics.csv',
#      'source_field': 'Sex',
#      'term_mapping': {'Male': 8507}},
#     'gender_source_concept_id': {'source_table': 'Demographics.csv',
#      'source_field': 'Sex',
#      'term_mapping': {'Male': 8507}},
#     'gender_source_value': {'source_table': 'Demographics.csv',
#      'source_field': 'Sex'},
#     'person_id': {'source_table': 'Demographics.csv', 'source_field': 'ID'}},
#    'FEMALE 3026': {'birth_datetime': {'source_table': 'Demographics.csv',
#      'source_field': 'Age',
#      'operations': ['get_datetime_from_age']},
#     'gender_concept_id': {'source_table': 'Demographics.csv',
#      'source_field': 'Sex',
#      'term_mapping': {'Female': 8532}},
#     'gender_source_concept_id': {'source_table': 'Demographics.csv',
#      'source_field': 'Sex',
#      'term_mapping': {'Female': 8532}},
#     'gender_source_value': {'source_table': 'Demographics.csv',
#      'source_field': 'Sex'},
#     'person_id': {'source_table': 'Demographics.csv', 'source_field': 'ID'}}},
#   'observation': {'Antibody 3027': {'observation_concept_id': {'source_table': 'Serology.csv',
#      'source_field': 'IgG',
#      'term_mapping': 4288455},
#     'observation_datetime': {'source_table': 'Serology.csv',
#      'source_field': 'Date'},
#     'observation_source_concept_id': {'source_table': 'Serology.csv',
#      'source_field': 'IgG',
#      'term_mapping': 4288455},
#     'observation_source_value': {'source_table': 'Serology.csv',
#      'source_field': 'IgG'},
#     'person_id': {'source_table': 'Serology.csv', 'source_field': 'ID'}}}}}

# %% [markdown]
# Create a common data model object and process it to create CDM tables

# %%
cdm = coconnect.cdm.CommonDataModel.from_rules(rules,inputs=sql_inputs)
cdm.process()
# Out:
# 2022-03-16 16:38:03 - CommonDataModel - INFO - CommonDataModel (5.3.1) created with co-connect-tools version 0.0.0
# 2022-03-16 16:38:03 - CommonDataModel - INFO - Running with an DataCollection object
# 2022-03-16 16:38:03 - CommonDataModel - INFO - Turning on automatic cdm column filling
# 2022-03-16 16:38:03 - CommonDataModel - INFO - Added MALE 3025 of type person
# 2022-03-16 16:38:03 - CommonDataModel - INFO - Added FEMALE 3026 of type person
# 2022-03-16 16:38:03 - CommonDataModel - INFO - Added Antibody 3027 of type observation
# 2022-03-16 16:38:03 - CommonDataModel - INFO - Starting processing in order: ['person', 'observation']
# 2022-03-16 16:38:03 - CommonDataModel - INFO - Number of objects to process for each table...
# {
#       "person": 2,
#       "observation": 1
# }
# 2022-03-16 16:38:03 - CommonDataModel - INFO - for person: found 2 objects
# 2022-03-16 16:38:03 - CommonDataModel - INFO - working on person
# 2022-03-16 16:38:03 - CommonDataModel - INFO - starting on MALE 3025
# 2022-03-16 16:38:03 - Person - INFO - Called apply_rules
# 2022-03-16 16:38:03 - LocalDataCollection - INFO - Retrieving initial dataframe for 'Demographics.csv' for the first time
# 2022-03-16 16:38:03 - Person - INFO - Mapped birth_datetime
# 2022-03-16 16:38:03 - Person - INFO - Mapped gender_concept_id
# 2022-03-16 16:38:03 - Person - INFO - Mapped gender_source_concept_id
# 2022-03-16 16:38:03 - Person - INFO - Mapped gender_source_value
# 2022-03-16 16:38:03 - Person - INFO - Mapped person_id
# 2022-03-16 16:38:03 - Person - WARNING - Requiring non-null values in gender_concept_id removed 454 rows, leaving 546 rows.
# 2022-03-16 16:38:03 - Person - INFO - Automatically formatting data columns.
# 2022-03-16 16:38:03 - Person - INFO - created df (0x128dbc5e0)[MALE_3025]
# 2022-03-16 16:38:03 - CommonDataModel - INFO - finished MALE 3025 (0x128dbc5e0) ... 1/2 completed, 546 rows
# 2022-03-16 16:38:03 - CommonDataModel - INFO - starting on FEMALE 3026
# 2022-03-16 16:38:03 - Person - INFO - Called apply_rules
# 2022-03-16 16:38:03 - Person - INFO - Mapped birth_datetime
# 2022-03-16 16:38:03 - Person - INFO - Mapped gender_concept_id
# 2022-03-16 16:38:03 - Person - INFO - Mapped gender_source_concept_id
# 2022-03-16 16:38:03 - Person - INFO - Mapped gender_source_value
# 2022-03-16 16:38:03 - Person - INFO - Mapped person_id
# 2022-03-16 16:38:03 - Person - WARNING - Requiring non-null values in gender_concept_id removed 551 rows, leaving 449 rows.
# 2022-03-16 16:38:03 - Person - INFO - Automatically formatting data columns.
# 2022-03-16 16:38:03 - Person - INFO - created df (0x1243cc190)[FEMALE_3026]
# 2022-03-16 16:38:03 - CommonDataModel - INFO - finished FEMALE 3026 (0x1243cc190) ... 2/2 completed, 449 rows
# 2022-03-16 16:38:03 - CommonDataModel - INFO - called save_dateframe but outputs are not defined. save_files: True
# 2022-03-16 16:38:03 - CommonDataModel - INFO - finalised person on iteration 0 producing 995 rows from 2 tables
# 2022-03-16 16:38:03 - LocalDataCollection - INFO - Getting next chunk of data
# 2022-03-16 16:38:03 - LocalDataCollection - INFO - All input files for this object have now been used.
# 2022-03-16 16:38:03 - LocalDataCollection - INFO - resetting used bricks
# 2022-03-16 16:38:03 - CommonDataModel - INFO - for observation: found 1 object
# 2022-03-16 16:38:03 - CommonDataModel - INFO - working on observation
# 2022-03-16 16:38:03 - CommonDataModel - INFO - starting on Antibody 3027
# 2022-03-16 16:38:03 - Observation - INFO - Called apply_rules
# 2022-03-16 16:38:03 - LocalDataCollection - INFO - Retrieving initial dataframe for 'Serology.csv' for the first time
# 2022-03-16 16:38:03 - Observation - INFO - Mapped observation_concept_id
# 2022-03-16 16:38:03 - Observation - INFO - Mapped observation_datetime
# 2022-03-16 16:38:03 - Observation - INFO - Mapped observation_source_concept_id
# 2022-03-16 16:38:03 - Observation - INFO - Mapped observation_source_value
# 2022-03-16 16:38:03 - Observation - INFO - Mapped person_id
# 2022-03-16 16:38:03 - Observation - INFO - Automatically formatting data columns.
# 2022-03-16 16:38:03 - Observation - INFO - created df (0x128dbc8b0)[Antibody_3027]
# 2022-03-16 16:38:03 - CommonDataModel - INFO - finished Antibody 3027 (0x128dbc8b0) ... 1/1 completed, 363 rows
# 2022-03-16 16:38:03 - CommonDataModel - ERROR - There are person_ids in this table that are not in the output person table!
# 2022-03-16 16:38:03 - CommonDataModel - ERROR - Either they are not in the original data, or while creating the person table,
# 2022-03-16 16:38:03 - CommonDataModel - ERROR - studies have been removed due to lack of required fields, such as birthdate.
# 2022-03-16 16:38:03 - CommonDataModel - ERROR - 359/363 were good, 4 studies are removed.
# 2022-03-16 16:38:03 - CommonDataModel - INFO - called save_dateframe but outputs are not defined. save_files: True
# 2022-03-16 16:38:03 - CommonDataModel - INFO - finalised observation on iteration 0 producing 359 rows from 1 tables
# 2022-03-16 16:38:03 - LocalDataCollection - INFO - Getting next chunk of data
# 2022-03-16 16:38:03 - LocalDataCollection - INFO - All input files for this object have now been used.

# %%
cdm['person'].dropna(axis=1)
# Out:
#            gender_concept_id  year_of_birth  month_of_birth  day_of_birth  \
# person_id
# 1                       8507           1947               7            20
# 2                       8507           1962               7            16
# 3                       8507           1957               7            17
# 4                       8507           1946               7            20
# 5                       8507           1944               7            20
# ...                      ...            ...             ...           ...
# 991                     8532           1944               7            20
# 992                     8532           1951               7            19
# 993                     8532           1938               7            22
# 994                     8532           1959               7            17
# 995                     8532           1972               7            13
#
#                        birth_datetime gender_source_value  \
# person_id
# 1          1947-07-20 00:00:00.000000                Male
# 2          1962-07-16 00:00:00.000000                Male
# 3          1957-07-17 00:00:00.000000                Male
# 4          1946-07-20 00:00:00.000000                Male
# 5          1944-07-20 00:00:00.000000                Male
# ...                               ...                 ...
# 991        1944-07-20 00:00:00.000000              Female
# 992        1951-07-19 00:00:00.000000              Female
# 993        1938-07-22 00:00:00.000000              Female
# 994        1959-07-17 00:00:00.000000              Female
# 995        1972-07-13 00:00:00.000000              Female
#
#            gender_source_concept_id
# person_id
# 1                              8507
# 2                              8507
# 3                              8507
# 4                              8507
# 5                              8507
# ...                             ...
# 991                            8532
# 992                            8532
# 993                            8532
# 994                            8532
# 995                            8532
#
# [995 rows x 7 columns]

# %%
cdm['observation'].dropna(axis=1)
# Out:
#                 person_id  observation_concept_id observation_date  \
# observation_id
# 1                     880                 4288455       2020-03-29
# 2                     638                 4288455       2022-07-26
# 3                     654                 4288455       2019-10-15
# 4                     286                 4288455       2022-01-08
# 5                      19                 4288455       2022-04-12
# ...                   ...                     ...              ...
# 359                   161                 4288455       2023-03-17
# 360                   570                 4288455       2020-03-09
# 361                   726                 4288455       2020-11-09
# 362                   679                 4288455       2019-08-26
# 363                   320                 4288455       2021-08-15
#
#                       observation_datetime observation_source_value  \
# observation_id
# 1               2020-03-29 00:00:00.000000       40.481862620281696
# 2               2022-07-26 00:00:00.000000        9.057812397131036
# 3               2019-10-15 00:00:00.000000        6.761957236947811
# 4               2022-01-08 00:00:00.000000       1.9819726698915583
# 5               2022-04-12 00:00:00.000000        1.441420109316674
# ...                                    ...                      ...
# 359             2023-03-17 00:00:00.000000        66.71490996683399
# 360             2020-03-09 00:00:00.000000        31.55637115308043
# 361             2020-11-09 00:00:00.000000       15.658884987181032
# 362             2019-08-26 00:00:00.000000        6.093197917384714
# 363             2021-08-15 00:00:00.000000         1.87775362427298
#
#                 observation_source_concept_id
# observation_id
# 1                                     4288455
# 2                                     4288455
# 3                                     4288455
# 4                                     4288455
# 5                                     4288455
# ...                                       ...
# 359                                   4288455
# 360                                   4288455
# 361                                   4288455
# 362                                   4288455
# 363                                   4288455
#
# [359 rows x 6 columns]

# %% [markdown]
# ## PySpark
#
# Using `PySpark` we can create a session and a reader to connect to the same SQL database we created above

# %%
from pyspark.sql import SparkSession

# %% [markdown]
# Define the session:

# %%
spark = SparkSession \
    .builder \
    .appName("Python Spark SQL basic example") \
    .config("spark.jars", "/Users/calummacdonald/Downloads/postgresql-42.3.1.jar") \
    .getOrCreate()

# %% [markdown]
# Create a reader:

# %%
reader = spark.read \
    .format("jdbc") \
    .option("url", "jdbc:postgresql://localhost:5432/ExampleCOVID19DataSet") \
    .option("driver", "org.postgresql.Driver") 
reader

# %% [markdown]
# Create and load a spark dataframe for the Demographics table and specify to filter this on all people under the age of 20, selecting only the first 2000 rows:

# %%
sdf_demo = reader.option("dbtable", '"Demographics"')\
                 .load()\

sdf_demo = sdf_demo.filter(sdf_demo.Age<20).limit(2000)

# %% [markdown]
# Select the first 1000 rows:

# %%
sdf_demo_first = sdf_demo.limit(1000)

# %% [markdown]
# Drop the first 1000 rows by subtracting the first 1000:

# %%
sdf_demo = sdf_demo.subtract(sdf_demo_first).limit(1000)
sdf_demo
# Out:
# DataFrame[ID: string, Age: double, Sex: string, Ethnicity: string, IMD: bigint]

# %% [markdown]
# Load the serology table, selecting only those whos ID is in the already loaded spark dataframe for the demographics

# %%
sdf_serology = reader.option("dbtable", '"Serology"')\
                     .load()

sdf_serology = sdf_serology.join(sdf_demo,
                                 ['ID'])\
                            .select(*sdf_serology.columns)
                         
sdf_serology.count()
# Out:
# 390

# %% [markdown]
# Retrieve pandas dataframes from these spark dataframes and put them in a new map
# _note_: we keep the name as '.csv' because this is what the name is in the rules file!

# %%
df_map = {
            'Demographics.csv': sdf_demo.select('*').toPandas(),
            'Serology.csv': sdf_serology.select('*').toPandas()
         }

# %%
spark_inputs = coconnect.io.LocalDataCollection()
spark_inputs.load_input_dataframe(df_map)
spark_inputs
# Out:
# 2022-03-16 16:43:17 - LocalDataCollection - INFO - DataCollection Object Created
# 2022-03-16 16:43:17 - LocalDataCollection - INFO - Registering  Demographics.csv [<coconnect.io.common.DataBrick object at 0x1245dcb50>]
# 2022-03-16 16:43:17 - LocalDataCollection - INFO - Registering  Serology.csv [<coconnect.io.common.DataBrick object at 0x1245dc940>]

# %%
cdm = coconnect.cdm.CommonDataModel.from_rules(rules,inputs=spark_inputs)
cdm.process()
# Out:
# 2022-03-16 16:43:32 - CommonDataModel - INFO - CommonDataModel (5.3.1) created with co-connect-tools version 0.0.0
# 2022-03-16 16:43:32 - CommonDataModel - INFO - Running with an DataCollection object
# 2022-03-16 16:43:32 - CommonDataModel - INFO - Turning on automatic cdm column filling
# 2022-03-16 16:43:32 - CommonDataModel - INFO - Added MALE 3025 of type person
# 2022-03-16 16:43:32 - CommonDataModel - INFO - Added FEMALE 3026 of type person
# 2022-03-16 16:43:32 - CommonDataModel - INFO - Added Antibody 3027 of type observation
# 2022-03-16 16:43:32 - CommonDataModel - INFO - Starting processing in order: ['person', 'observation']
# 2022-03-16 16:43:32 - CommonDataModel - INFO - Number of objects to process for each table...
# {
#       "person": 2,
#       "observation": 1
# }
# 2022-03-16 16:43:32 - CommonDataModel - INFO - for person: found 2 objects
# 2022-03-16 16:43:32 - CommonDataModel - INFO - working on person
# 2022-03-16 16:43:32 - CommonDataModel - INFO - starting on MALE 3025
# 2022-03-16 16:43:32 - Person - INFO - Called apply_rules
# 2022-03-16 16:43:32 - LocalDataCollection - INFO - Retrieving initial dataframe for 'Demographics.csv' for the first time
# 2022-03-16 16:43:32 - Person - INFO - Mapped birth_datetime
# 2022-03-16 16:43:32 - Person - INFO - Mapped gender_concept_id
# 2022-03-16 16:43:32 - Person - INFO - Mapped gender_source_concept_id
# 2022-03-16 16:43:32 - Person - INFO - Mapped gender_source_value
# 2022-03-16 16:43:32 - Person - INFO - Mapped person_id
# 2022-03-16 16:43:32 - Person - WARNING - Requiring non-null values in gender_concept_id removed 435 rows, leaving 565 rows.
# 2022-03-16 16:43:32 - Person - INFO - Automatically formatting data columns.
# 2022-03-16 16:43:32 - Person - INFO - created df (0x127636340)[MALE_3025]
# 2022-03-16 16:43:32 - CommonDataModel - INFO - finished MALE 3025 (0x127636340) ... 1/2 completed, 565 rows
# 2022-03-16 16:43:32 - CommonDataModel - INFO - starting on FEMALE 3026
# 2022-03-16 16:43:32 - Person - INFO - Called apply_rules
# 2022-03-16 16:43:32 - Person - INFO - Mapped birth_datetime
# 2022-03-16 16:43:32 - Person - INFO - Mapped gender_concept_id
# 2022-03-16 16:43:32 - Person - INFO - Mapped gender_source_concept_id
# 2022-03-16 16:43:32 - Person - INFO - Mapped gender_source_value
# 2022-03-16 16:43:32 - Person - INFO - Mapped person_id
# 2022-03-16 16:43:32 - Person - WARNING - Requiring non-null values in gender_concept_id removed 567 rows, leaving 433 rows.
# 2022-03-16 16:43:33 - Person - INFO - Automatically formatting data columns.
# 2022-03-16 16:43:33 - Person - INFO - created df (0x124832100)[FEMALE_3026]
# 2022-03-16 16:43:33 - CommonDataModel - INFO - finished FEMALE 3026 (0x124832100) ... 2/2 completed, 433 rows
# 2022-03-16 16:43:33 - CommonDataModel - INFO - called save_dateframe but outputs are not defined. save_files: True
# 2022-03-16 16:43:33 - CommonDataModel - INFO - finalised person on iteration 0 producing 998 rows from 2 tables
# 2022-03-16 16:43:33 - LocalDataCollection - INFO - Getting next chunk of data
# 2022-03-16 16:43:33 - LocalDataCollection - INFO - All input files for this object have now been used.
# 2022-03-16 16:43:33 - LocalDataCollection - INFO - resetting used bricks
# 2022-03-16 16:43:33 - CommonDataModel - INFO - for observation: found 1 object
# 2022-03-16 16:43:33 - CommonDataModel - INFO - working on observation
# 2022-03-16 16:43:33 - CommonDataModel - INFO - starting on Antibody 3027
# 2022-03-16 16:43:33 - Observation - INFO - Called apply_rules
# 2022-03-16 16:43:33 - LocalDataCollection - INFO - Retrieving initial dataframe for 'Serology.csv' for the first time
# 2022-03-16 16:43:33 - Observation - INFO - Mapped observation_concept_id
# 2022-03-16 16:43:33 - Observation - INFO - Mapped observation_datetime
# 2022-03-16 16:43:33 - Observation - INFO - Mapped observation_source_concept_id
# 2022-03-16 16:43:33 - Observation - INFO - Mapped observation_source_value
# 2022-03-16 16:43:33 - Observation - INFO - Mapped person_id
# 2022-03-16 16:43:33 - Observation - INFO - Automatically formatting data columns.
# 2022-03-16 16:43:33 - Observation - INFO - created df (0x1248877c0)[Antibody_3027]
# 2022-03-16 16:43:33 - CommonDataModel - INFO - finished Antibody 3027 (0x1248877c0) ... 1/1 completed, 390 rows
# 2022-03-16 16:43:33 - CommonDataModel - ERROR - There are person_ids in this table that are not in the output person table!
# 2022-03-16 16:43:33 - CommonDataModel - ERROR - Either they are not in the original data, or while creating the person table,
# 2022-03-16 16:43:33 - CommonDataModel - ERROR - studies have been removed due to lack of required fields, such as birthdate.
# 2022-03-16 16:43:33 - CommonDataModel - ERROR - 389/390 were good, 1 studies are removed.
# 2022-03-16 16:43:33 - CommonDataModel - INFO - called save_dateframe but outputs are not defined. save_files: True
# 2022-03-16 16:43:33 - CommonDataModel - INFO - finalised observation on iteration 0 producing 389 rows from 1 tables
# 2022-03-16 16:43:33 - LocalDataCollection - INFO - Getting next chunk of data
# 2022-03-16 16:43:33 - LocalDataCollection - INFO - All input files for this object have now been used.

# %%
cdm['observation'].dropna(axis=1)
# Out:
#                 person_id  observation_concept_id observation_date  \
# observation_id
# 1                     709                 4288455       2021-03-19
# 2                      12                 4288455       2019-10-10
# 3                     756                 4288455       2020-09-30
# 4                     389                 4288455       2021-10-17
# 5                     328                 4288455       2022-01-03
# ...                   ...                     ...              ...
# 386                   931                 4288455       2020-08-12
# 387                    84                 4288455       2020-10-26
# 388                   216                 4288455       2020-05-23
# 389                    12                 4288455       2020-12-19
# 390                   666                 4288455       2020-12-08
#
#                       observation_datetime observation_source_value  \
# observation_id
# 1               2021-03-19 00:00:00.000000       2.4434023669112914
# 2               2019-10-10 00:00:00.000000        2.524992108387176
# 3               2020-09-30 00:00:00.000000        2.498767194399477
# 4               2021-10-17 00:00:00.000000        65.13603812569892
# 5               2022-01-03 00:00:00.000000        38.47070924884126
# ...                                    ...                      ...
# 386             2020-08-12 00:00:00.000000        36.53392857849371
# 387             2020-10-26 00:00:00.000000        26.51166231662655
# 388             2020-05-23 00:00:00.000000       28.424229915504444
# 389             2020-12-19 00:00:00.000000       24.663227817629537
# 390             2020-12-08 00:00:00.000000        77.07087446876402
#
#                 observation_source_concept_id
# observation_id
# 1                                     4288455
# 2                                     4288455
# 3                                     4288455
# 4                                     4288455
# 5                                     4288455
# ...                                       ...
# 386                                   4288455
# 387                                   4288455
# 388                                   4288455
# 389                                   4288455
# 390                                   4288455
#
# [389 rows x 6 columns]

# %%
cdm['person'].dropna(axis=1)
# Out:
#            gender_concept_id  year_of_birth  month_of_birth  day_of_birth  \
# person_id
# 1                       8507           2003               7             6
# 2                       8507           2001               7             6
# 3                       8507           2006               7             5
# 4                       8507           2001               7             6
# 5                       8507           2001               7             6
# ...                      ...            ...             ...           ...
# 994                     8532           2008               7             4
# 995                     8532           2009               7             4
# 996                     8532           2006               7             5
# 997                     8532           2011               7             4
# 998                     8532           2005               7             5
#
#                        birth_datetime gender_source_value  \
# person_id
# 1          2003-07-06 00:00:00.000000                Male
# 2          2001-07-06 00:00:00.000000                Male
# 3          2006-07-05 00:00:00.000000                Male
# 4          2001-07-06 00:00:00.000000                Male
# 5          2001-07-06 00:00:00.000000                Male
# ...                               ...                 ...
# 994        2008-07-04 00:00:00.000000              Female
# 995        2009-07-04 00:00:00.000000              Female
# 996        2006-07-05 00:00:00.000000              Female
# 997        2011-07-04 00:00:00.000000              Female
# 998        2005-07-05 00:00:00.000000              Female
#
#            gender_source_concept_id
# person_id
# 1                              8507
# 2                              8507
# 3                              8507
# 4                              8507
# 5                              8507
# ...                             ...
# 994                            8532
# 995                            8532
# 996                            8532
# 997                            8532
# 998                            8532
#
# [998 rows x 7 columns]
